# %%
import requests
import json
from typing import List, Dict, Any

class DatabaseTypeFieldUpdater:
    def __init__(self, api_base_url: str = "http://localhost:3000/api/contracts"):
        self.api_base_url = api_base_url
    
    def fetch_all_contracts(self) -> List[Dict[str, Any]]:
        """Fetch all contracts from the database"""
        try:
            response = requests.get(self.api_base_url)
            if response.status_code == 200:
                contracts = response.json()
                print(f"✓ Fetched {len(contracts)} contracts from database")
                return contracts
            else:
                print(f"✗ Error fetching contracts: {response.status_code}")
                return []
        except Exception as e:
            print(f"✗ Error fetching contracts: {e}")
            return []
    
    def determine_type_from_name(self, contract_name: str) -> str:
        """Determine the Type based on contract name"""
        if "(LGC)" in contract_name:
            return "Green"
        else:
            return "Energy"
    
    def update_contract_with_type(self, contract: Dict[str, Any]) -> bool:
        """Update a single contract to add the Type field"""
        try:
            contract_id = contract.get('_id')
            if not contract_id:
                print(f"✗ No ID found for contract: {contract.get('name', 'Unknown')}")
                return False
            
            # Determine the Type based on contract name
            contract_name = contract.get('name', '')
            contract_type = self.determine_type_from_name(contract_name)
            
            # Prepare update payload - only add Type field, keep existing unit
            update_payload = {
                'id': contract_id,
                'contractType': contract_type  # Add the new Type field
            }
            
            # Make API call to update contract
            response = requests.put(self.api_base_url, json=update_payload)
            
            if response.status_code == 200:
                print(f"✓ Updated contract: {contract_name} → Type: {contract_type}")
                return True
            else:
                print(f"✗ Error updating contract {contract_name}: {response.status_code} - {response.text}")
                return False
                
        except Exception as e:
            print(f"✗ Error updating contract {contract.get('name', 'Unknown')}: {e}")
            return False
    
    def preview_changes(self, contracts: List[Dict[str, Any]]) -> None:
        """Preview what changes will be made"""
        print("\n" + "="*80)
        print("PREVIEW OF CHANGES")
        print("="*80)
        
        energy_count = 0
        green_count = 0
        
        for contract in contracts:
            name = contract.get('name', 'Unknown')
            current_unit = contract.get('unit', 'N/A')
            new_type = self.determine_type_from_name(name)
            
            if new_type == "Green":
                green_count += 1
                print(f"🟢 {name}")
                print(f"   Current unit: {current_unit} → Will add Type: Green")
            else:
                energy_count += 1
                print(f"🔵 {name}")
                print(f"   Current unit: {current_unit} → Will add Type: Energy")
        
        print(f"\nSummary:")
        print(f"  Contracts to be set to Type 'Energy': {energy_count}")
        print(f"  Contracts to be set to Type 'Green': {green_count}")
        print(f"  Total contracts: {len(contracts)}")
        print(f"  Note: Existing 'unit' field will be preserved")
    
    def update_all_contracts(self, dry_run: bool = True) -> None:
        """Main method to update all contracts with Type field"""
        print("Starting database Type field addition process...")
        print(f"Mode: {'DRY RUN (preview only)' if dry_run else 'LIVE UPDATE'}")
        
        # Fetch all contracts
        contracts = self.fetch_all_contracts()
        if not contracts:
            print("No contracts found. Exiting.")
            return
        
        # Preview changes
        self.preview_changes(contracts)
        
        if dry_run:
            print(f"\n{'='*80}")
            print("DRY RUN COMPLETE")
            print("="*80)
            print("This was a preview. To execute the updates, run with dry_run=False")
            return
        
        # Confirm before proceeding with live updates
        print(f"\n{'='*80}")
        print("READY TO EXECUTE LIVE UPDATES")
        print("="*80)
        confirm = input("Are you sure you want to proceed? (y/N): ").strip().lower()
        
        if confirm != 'y':
            print("Update cancelled.")
            return
        
        # Execute updates
        print("\nExecuting updates...")
        success_count = 0
        error_count = 0
        
        for contract in contracts:
            if self.update_contract_with_type(contract):
                success_count += 1
            else:
                error_count += 1
        
        # Final summary
        print(f"\n{'='*80}")
        print("UPDATE SUMMARY")
        print("="*80)
        print(f"Successfully updated: {success_count}")
        print(f"Errors: {error_count}")
        print(f"Total processed: {len(contracts)}")
        
        if error_count == 0:
            print("🎉 All contracts updated successfully!")
        else:
            print(f"⚠️  {error_count} contracts had errors during update")

# Example usage
if __name__ == "__main__":
    updater = DatabaseTypeFieldUpdater("http://localhost:3000/api/contracts")
    
    # First run a dry run to preview changes
    print("=== DRY RUN: Preview Changes ===")
    updater.update_all_contracts(dry_run=False)
    
    # Uncomment the line below to execute the actual updates
    # print("\n=== LIVE UPDATE: Execute Changes ===")
    # updater.update_all_contracts(dry_run=False)
# Out:
# === DRY RUN: Preview Changes ===
# Starting database Type field addition process...
# Mode: LIVE UPDATE
# ✓ Fetched 354 contracts from database
#
# ================================================================================
# PREVIEW OF CHANGES
# ================================================================================
# 🔵 BVC TOU
#    Current unit: Energy → Will add Type: Energy
# 🟢 BVC TOU (LGC)
#    Current unit: Green → Will add Type: Green
# 🔵 CSIRO TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 CSIRO TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Fairfield Non-TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Fairfield Non-TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Fairfield TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Fairfield TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 SBS TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 SBS TOU (LGC)
#    Current unit: Green → Will add Type: Green
# 🔵 SSROC Non-TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 SSROC Non-TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 SSROC TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 SSROC TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 ISPT TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 ISPT TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Adelaide Metro Non-TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Adelaide Metro Non-TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Adelaide Metro TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Adelaide Metro TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Bunnings TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Bunnings TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 CBUS TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 CBUS TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Hentley Farm TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Hentley Farm TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 KMART&TARGET TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 KMART&TARGET TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 SA Government Non-TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 SA Government Non-TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 SACOME TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 SACOME TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Sarstedt TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Sarstedt TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Sekisui TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Sekisui TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 St John Ambulance Non-TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 St John Ambulance Non-TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Sundrop Farms TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Sundrop Farms TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Kings The Printer TOU
#    Current unit: MWh → Will add Type: Energy
# 🔵 SEEK TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 SEEK TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Villa Maria TOU
#    Current unit: MWh → Will add Type: Energy
# 🟢 Villa Maria TOU (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Blue Grass Solar 202203
#    Current unit: MWh → Will add Type: Energy
# 🟢 Blue Grass Solar 202203 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Cathedral Rocks Wind 202408
#    Current unit: MWh → Will add Type: Energy
# 🟢 Cathedral Rocks Wind 202408 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Collector Wind 202403
#    Current unit: MWh → Will add Type: Energy
# 🟢 Collector Wind 202403 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Diapur Wind 202212
#    Current unit: MWh → Will add Type: Energy
# 🟢 Diapur Wind 202212 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Edenvale Solar 202411
#    Current unit: MWh → Will add Type: Energy
# 🔵 Ferguson Wind 202212
#    Current unit: MWh → Will add Type: Energy
# 🟢 Ferguson Wind 202212 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Ginan Solar 202406
#    Current unit: MWh → Will add Type: Energy
# 🟢 Ginan Solar 202406 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Gunnedah Solar 202407
#    Current unit: MWh → Will add Type: Energy
# 🔵 Hay Solar 202409
#    Current unit: MWh → Will add Type: Energy
# 🔵 Hillston 1 Solar 202409
#    Current unit: MWh → Will add Type: Energy
# 🔵 Hillston 2 Solar 202409
#    Current unit: MWh → Will add Type: Energy
# 🔵 Kerang Solar 202408
#    Current unit: MWh → Will add Type: Energy
# 🟢 Kerang Solar 202408 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Kootingal Solar 202407
#    Current unit: MWh → Will add Type: Energy
# 🔵 Moree Solar 202202
#    Current unit: MWh → Will add Type: Energy
# 🟢 Moree Solar 202202 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Mortons Lane Wind 202212
#    Current unit: MWh → Will add Type: Energy
# 🟢 Mortons Lane Wind 202212 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Mulwala Solar 202209
#    Current unit: MWh → Will add Type: Energy
# 🟢 Mulwala Solar 202209 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 New England Solar 202412
#    Current unit: MWh → Will add Type: Energy
# 🟢 New England Solar 202412 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Numurkah Solar 201810
#    Current unit: MWh → Will add Type: Energy
# 🟢 Numurkah Solar 201810 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Numurkah Solar 202410
#    Current unit: MWh → Will add Type: Energy
# 🟢 Numurkah Solar 202410 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Nyngan Solar 202212
#    Current unit: MWh → Will add Type: Energy
# 🟢 Nyngan Solar 202212 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Quorn Solar 202406
#    Current unit: MWh → Will add Type: Energy
# 🟢 Quorn Solar 202406 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Renmark Solar 202212
#    Current unit: MWh → Will add Type: Energy
# 🔵 Starfish Hill Wind 202403
#    Current unit: MWh → Will add Type: Energy
# 🟢 Starfish Hill Wind 202403 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Tailem Bend 2 Solar 202203
#    Current unit: MWh → Will add Type: Energy
# 🔵 Temora Solar 202407
#    Current unit: MWh → Will add Type: Energy
# 🔵 Wagga Wagga Solar 202303
#    Current unit: MWh → Will add Type: Energy
# 🟢 Wagga Wagga Solar 202303 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Waubra Wind 202208
#    Current unit: MWh → Will add Type: Energy
# 🟢 Waubra Wind 202208 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Waubra Wind 202401
#    Current unit: MWh → Will add Type: Energy
# 🟢 Waubra Wind 202401 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Wemen Solar 201806
#    Current unit: MWh → Will add Type: Energy
# 🟢 Wemen Solar 201806 (LGC)
#    Current unit: MWh → Will add Type: Green
# 🔵 Woods Point Solar 202304
#    Current unit: MWh → Will add Type: Energy
# 🔵 NSW Retail FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Retail FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Retail FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Retail FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Solar FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Solar FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Solar FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Solar FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Wind FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Wind FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Wind FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 NSW Wind FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 QLD Retail FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 QLD Retail FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 QLD Solar FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 QLD Solar FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 QLD Solar FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 QLD Solar FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Retail FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Retail FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Retail FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Retail FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Solar FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Solar FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Solar FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Solar FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Wind FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Wind FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Wind FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 SA Wind FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 SE000352
#    Current unit: MW → Will add Type: Energy
# 🔵 SE000354
#    Current unit: MW → Will add Type: Energy
# 🟢 SE000780 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE000960 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001052 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001062
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001063
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001088
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001089
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001106 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001139 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001191 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001194
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001272 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001282 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001317 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001327
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001350 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001368 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001369
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001392 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001399 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001416 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001447
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001449
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001452
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001453
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001455
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001470
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001479
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001480 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001482 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001490
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001494
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001498 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001513
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001514
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001515 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001516
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001517
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001523 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001541 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001547
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001550 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001551 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001573
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001574 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001575 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001578 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001593 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001600 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001620
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001628 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001629 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001639 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE001641 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001642
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001646
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001648
#    Current unit: MW → Will add Type: Energy
# 🟢 SE001660 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE001677
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001679
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001685
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001709
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001712
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001718
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001767
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001769
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001770
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001783
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001841
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001845
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001846
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001847
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001848
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001874
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001876
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001888
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001889
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001890
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001891
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001896
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001897
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001902
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001903
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001904
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001905
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001906
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001907
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001908
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001912
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001913
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001914
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001916
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001917
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001920
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001921
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001933
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001945
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001947
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001952
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001959
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001960
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001979
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001981
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001982
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001986
#    Current unit: MW → Will add Type: Energy
# 🔵 SE001989
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002021
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002049
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002050 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002051 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002052 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002053 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002054 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002055 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002056 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002057 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002058 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002059 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002060 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002061 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE002062
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002063
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002077
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002078
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002091
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002097 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE002103
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002105 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE002141
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002153
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002154
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002155
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002157
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002159 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE002161
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002163
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002164
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002165
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002166
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002169
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002171
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002172
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002173
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002174
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002175
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002176
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002178
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002179
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002180
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002182
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002183
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002184
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002185
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002186
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002191
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002193
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002194
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002195
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002196
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002197
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002198
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002199
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002200
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002201
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002202
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002203
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002211
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002212
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002213 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002214 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002215 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002216 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002217 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002218 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002219 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002220 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002221 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002222 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002223 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002224 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002225 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002226 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002227 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002228 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002229 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE002232
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002233
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002234
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002235
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002236
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002252 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002253 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002254 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE002255
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002256
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002257
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002258
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002259
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002260
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002262 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE002263
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002266 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002267 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 SE002268
#    Current unit: MW → Will add Type: Energy
# 🔵 SE002269
#    Current unit: MW → Will add Type: Energy
# 🟢 SE002270 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002271 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002272 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002273 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002274 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002275 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002276 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002277 (LGC)
#    Current unit: MW → Will add Type: Green
# 🟢 SE002278 (LGC)
#    Current unit: MW → Will add Type: Green
# 🔵 Templers
#    Current unit: MWh → Will add Type: Energy
# 🔵 VIC Retail FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Retail FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Retail FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Retail FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Solar FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Solar FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Solar FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Solar FY25 S
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Wind FY25 B
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Wind FY25 Cap B
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Wind FY25 Cap S
#    Current unit: MW → Will add Type: Energy
# 🔵 VIC Wind FY25 S
#    Current unit: MW → Will add Type: Energy
#
# Summary:
#   Contracts to be set to Type 'Energy': 233
#   Contracts to be set to Type 'Green': 121
#   Total contracts: 354
#   Note: Existing 'unit' field will be preserved
#
# ================================================================================
# READY TO EXECUTE LIVE UPDATES
# ================================================================================
#
# Executing updates...
# ✓ Updated contract: BVC TOU → Type: Energy
# ✓ Updated contract: BVC TOU (LGC) → Type: Green
# ✓ Updated contract: CSIRO TOU → Type: Energy
# ✓ Updated contract: CSIRO TOU (LGC) → Type: Green
# ✓ Updated contract: Fairfield Non-TOU → Type: Energy
# ✓ Updated contract: Fairfield Non-TOU (LGC) → Type: Green
# ✓ Updated contract: Fairfield TOU → Type: Energy
# ✓ Updated contract: Fairfield TOU (LGC) → Type: Green
# ✓ Updated contract: SBS TOU → Type: Energy
# ✓ Updated contract: SBS TOU (LGC) → Type: Green
# ✓ Updated contract: SSROC Non-TOU → Type: Energy
# ✓ Updated contract: SSROC Non-TOU (LGC) → Type: Green
# ✓ Updated contract: SSROC TOU → Type: Energy
# ✓ Updated contract: SSROC TOU (LGC) → Type: Green
# ✓ Updated contract: ISPT TOU → Type: Energy
# ✓ Updated contract: ISPT TOU (LGC) → Type: Green
# ✓ Updated contract: Adelaide Metro Non-TOU → Type: Energy
# ✓ Updated contract: Adelaide Metro Non-TOU (LGC) → Type: Green
# ✓ Updated contract: Adelaide Metro TOU → Type: Energy
# ✓ Updated contract: Adelaide Metro TOU (LGC) → Type: Green
# ✓ Updated contract: Bunnings TOU → Type: Energy
# ✓ Updated contract: Bunnings TOU (LGC) → Type: Green
# ✓ Updated contract: CBUS TOU → Type: Energy
# ✓ Updated contract: CBUS TOU (LGC) → Type: Green
# ✓ Updated contract: Hentley Farm TOU → Type: Energy
# ✓ Updated contract: Hentley Farm TOU (LGC) → Type: Green
# ✓ Updated contract: KMART&TARGET TOU → Type: Energy
# ✓ Updated contract: KMART&TARGET TOU (LGC) → Type: Green
# ✓ Updated contract: SA Government Non-TOU → Type: Energy
# ✓ Updated contract: SA Government Non-TOU (LGC) → Type: Green
# ✓ Updated contract: SACOME TOU → Type: Energy
# ✓ Updated contract: SACOME TOU (LGC) → Type: Green
# ✓ Updated contract: Sarstedt TOU → Type: Energy
# ✓ Updated contract: Sarstedt TOU (LGC) → Type: Green
# ✓ Updated contract: Sekisui TOU → Type: Energy
# ✓ Updated contract: Sekisui TOU (LGC) → Type: Green
# ✓ Updated contract: St John Ambulance Non-TOU → Type: Energy
# ✓ Updated contract: St John Ambulance Non-TOU (LGC) → Type: Green
# ✓ Updated contract: Sundrop Farms TOU → Type: Energy
# ✓ Updated contract: Sundrop Farms TOU (LGC) → Type: Green
# ✓ Updated contract: Kings The Printer TOU → Type: Energy
# ✓ Updated contract: SEEK TOU → Type: Energy
# ✓ Updated contract: SEEK TOU (LGC) → Type: Green
# ✓ Updated contract: Villa Maria TOU → Type: Energy
# ✓ Updated contract: Villa Maria TOU (LGC) → Type: Green
# ✓ Updated contract: Blue Grass Solar 202203 → Type: Energy
# ✓ Updated contract: Blue Grass Solar 202203 (LGC) → Type: Green
# ✓ Updated contract: Cathedral Rocks Wind 202408 → Type: Energy
# ✓ Updated contract: Cathedral Rocks Wind 202408 (LGC) → Type: Green
# ✓ Updated contract: Collector Wind 202403 → Type: Energy
# ✓ Updated contract: Collector Wind 202403 (LGC) → Type: Green
# ✓ Updated contract: Diapur Wind 202212 → Type: Energy
# ✓ Updated contract: Diapur Wind 202212 (LGC) → Type: Green
# ✓ Updated contract: Edenvale Solar 202411 → Type: Energy
# ✓ Updated contract: Ferguson Wind 202212 → Type: Energy
# ✓ Updated contract: Ferguson Wind 202212 (LGC) → Type: Green
# ✓ Updated contract: Ginan Solar 202406 → Type: Energy
# ✓ Updated contract: Ginan Solar 202406 (LGC) → Type: Green
# ✓ Updated contract: Gunnedah Solar 202407 → Type: Energy
# ✓ Updated contract: Hay Solar 202409 → Type: Energy
# ✓ Updated contract: Hillston 1 Solar 202409 → Type: Energy
# ✓ Updated contract: Hillston 2 Solar 202409 → Type: Energy
# ✓ Updated contract: Kerang Solar 202408 → Type: Energy
# ✓ Updated contract: Kerang Solar 202408 (LGC) → Type: Green
# ✓ Updated contract: Kootingal Solar 202407 → Type: Energy
# ✓ Updated contract: Moree Solar 202202 → Type: Energy
# ✓ Updated contract: Moree Solar 202202 (LGC) → Type: Green
# ✓ Updated contract: Mortons Lane Wind 202212 → Type: Energy
# ✓ Updated contract: Mortons Lane Wind 202212 (LGC) → Type: Green
# ✓ Updated contract: Mulwala Solar 202209 → Type: Energy
# ✓ Updated contract: Mulwala Solar 202209 (LGC) → Type: Green
# ✓ Updated contract: New England Solar 202412 → Type: Energy
# ✓ Updated contract: New England Solar 202412 (LGC) → Type: Green
# ✓ Updated contract: Numurkah Solar 201810 → Type: Energy
# ✓ Updated contract: Numurkah Solar 201810 (LGC) → Type: Green
# ✓ Updated contract: Numurkah Solar 202410 → Type: Energy
# ✓ Updated contract: Numurkah Solar 202410 (LGC) → Type: Green
# ✓ Updated contract: Nyngan Solar 202212 → Type: Energy
# ✓ Updated contract: Nyngan Solar 202212 (LGC) → Type: Green
# ✓ Updated contract: Quorn Solar 202406 → Type: Energy
# ✓ Updated contract: Quorn Solar 202406 (LGC) → Type: Green
# ✓ Updated contract: Renmark Solar 202212 → Type: Energy
# ✓ Updated contract: Starfish Hill Wind 202403 → Type: Energy
# ✓ Updated contract: Starfish Hill Wind 202403 (LGC) → Type: Green
# ✓ Updated contract: Tailem Bend 2 Solar 202203 → Type: Energy
# ✓ Updated contract: Temora Solar 202407 → Type: Energy
# ✓ Updated contract: Wagga Wagga Solar 202303 → Type: Energy
# ✓ Updated contract: Wagga Wagga Solar 202303 (LGC) → Type: Green
# ✓ Updated contract: Waubra Wind 202208 → Type: Energy
# ✓ Updated contract: Waubra Wind 202208 (LGC) → Type: Green
# ✓ Updated contract: Waubra Wind 202401 → Type: Energy
# ✓ Updated contract: Waubra Wind 202401 (LGC) → Type: Green
# ✓ Updated contract: Wemen Solar 201806 → Type: Energy
# ✓ Updated contract: Wemen Solar 201806 (LGC) → Type: Green
# ✓ Updated contract: Woods Point Solar 202304 → Type: Energy
# ✓ Updated contract: NSW Retail FY25 B → Type: Energy
# ✓ Updated contract: NSW Retail FY25 Cap B → Type: Energy
# ✓ Updated contract: NSW Retail FY25 Cap S → Type: Energy
# ✓ Updated contract: NSW Retail FY25 S → Type: Energy
# ✓ Updated contract: NSW Solar FY25 B → Type: Energy
# ✓ Updated contract: NSW Solar FY25 Cap B → Type: Energy
# ✓ Updated contract: NSW Solar FY25 Cap S → Type: Energy
# ✓ Updated contract: NSW Solar FY25 S → Type: Energy
# ✓ Updated contract: NSW Wind FY25 B → Type: Energy
# ✓ Updated contract: NSW Wind FY25 Cap B → Type: Energy
# ✓ Updated contract: NSW Wind FY25 Cap S → Type: Energy
# ✓ Updated contract: NSW Wind FY25 S → Type: Energy
# ✓ Updated contract: QLD Retail FY25 B → Type: Energy
# ✓ Updated contract: QLD Retail FY25 S → Type: Energy
# ✓ Updated contract: QLD Solar FY25 B → Type: Energy
# ✓ Updated contract: QLD Solar FY25 Cap B → Type: Energy
# ✓ Updated contract: QLD Solar FY25 Cap S → Type: Energy
# ✓ Updated contract: QLD Solar FY25 S → Type: Energy
# ✓ Updated contract: SA Retail FY25 B → Type: Energy
# ✓ Updated contract: SA Retail FY25 Cap B → Type: Energy
# ✓ Updated contract: SA Retail FY25 Cap S → Type: Energy
# ✓ Updated contract: SA Retail FY25 S → Type: Energy
# ✓ Updated contract: SA Solar FY25 B → Type: Energy
# ✓ Updated contract: SA Solar FY25 Cap B → Type: Energy
# ✓ Updated contract: SA Solar FY25 Cap S → Type: Energy
# ✓ Updated contract: SA Solar FY25 S → Type: Energy
# ✓ Updated contract: SA Wind FY25 B → Type: Energy
# ✓ Updated contract: SA Wind FY25 Cap B → Type: Energy
# ✓ Updated contract: SA Wind FY25 Cap S → Type: Energy
# ✓ Updated contract: SA Wind FY25 S → Type: Energy
# ✓ Updated contract: SE000352 → Type: Energy
# ✓ Updated contract: SE000354 → Type: Energy
# ✓ Updated contract: SE000780 (LGC) → Type: Green
# ✓ Updated contract: SE000960 (LGC) → Type: Green
# ✓ Updated contract: SE001052 (LGC) → Type: Green
# ✓ Updated contract: SE001062 → Type: Energy
# ✓ Updated contract: SE001063 → Type: Energy
# ✓ Updated contract: SE001088 → Type: Energy
# ✓ Updated contract: SE001089 → Type: Energy
# ✓ Updated contract: SE001106 (LGC) → Type: Green
# ✓ Updated contract: SE001139 (LGC) → Type: Green
# ✓ Updated contract: SE001191 (LGC) → Type: Green
# ✓ Updated contract: SE001194 → Type: Energy
# ✓ Updated contract: SE001272 (LGC) → Type: Green
# ✓ Updated contract: SE001282 (LGC) → Type: Green
# ✓ Updated contract: SE001317 (LGC) → Type: Green
# ✓ Updated contract: SE001327 → Type: Energy
# ✓ Updated contract: SE001350 (LGC) → Type: Green
# ✓ Updated contract: SE001368 (LGC) → Type: Green
# ✓ Updated contract: SE001369 → Type: Energy
# ✓ Updated contract: SE001392 (LGC) → Type: Green
# ✓ Updated contract: SE001399 (LGC) → Type: Green
# ✓ Updated contract: SE001416 (LGC) → Type: Green
# ✓ Updated contract: SE001447 → Type: Energy
# ✓ Updated contract: SE001449 → Type: Energy
# ✓ Updated contract: SE001452 → Type: Energy
# ✓ Updated contract: SE001453 → Type: Energy
# ✓ Updated contract: SE001455 → Type: Energy
# ✓ Updated contract: SE001470 → Type: Energy
# ✓ Updated contract: SE001479 → Type: Energy
# ✓ Updated contract: SE001480 (LGC) → Type: Green
# ✓ Updated contract: SE001482 (LGC) → Type: Green
# ✓ Updated contract: SE001490 → Type: Energy
# ✓ Updated contract: SE001494 → Type: Energy
# ✓ Updated contract: SE001498 (LGC) → Type: Green
# ✓ Updated contract: SE001513 → Type: Energy
# ✓ Updated contract: SE001514 → Type: Energy
# ✓ Updated contract: SE001515 (LGC) → Type: Green
# ✓ Updated contract: SE001516 → Type: Energy
# ✓ Updated contract: SE001517 → Type: Energy
# ✓ Updated contract: SE001523 (LGC) → Type: Green
# ✓ Updated contract: SE001541 (LGC) → Type: Green
# ✓ Updated contract: SE001547 → Type: Energy
# ✓ Updated contract: SE001550 (LGC) → Type: Green
# ✓ Updated contract: SE001551 (LGC) → Type: Green
# ✓ Updated contract: SE001573 → Type: Energy
# ✓ Updated contract: SE001574 (LGC) → Type: Green
# ✓ Updated contract: SE001575 (LGC) → Type: Green
# ✓ Updated contract: SE001578 (LGC) → Type: Green
# ✓ Updated contract: SE001593 (LGC) → Type: Green
# ✓ Updated contract: SE001600 (LGC) → Type: Green
# ✓ Updated contract: SE001620 → Type: Energy
# ✓ Updated contract: SE001628 (LGC) → Type: Green
# ✓ Updated contract: SE001629 (LGC) → Type: Green
# ✓ Updated contract: SE001639 (LGC) → Type: Green
# ✓ Updated contract: SE001641 (LGC) → Type: Green
# ✓ Updated contract: SE001642 → Type: Energy
# ✓ Updated contract: SE001646 → Type: Energy
# ✓ Updated contract: SE001648 → Type: Energy
# ✓ Updated contract: SE001660 (LGC) → Type: Green
# ✓ Updated contract: SE001677 → Type: Energy
# ✓ Updated contract: SE001679 → Type: Energy
# ✓ Updated contract: SE001685 → Type: Energy
# ✓ Updated contract: SE001709 → Type: Energy
# ✓ Updated contract: SE001712 → Type: Energy
# ✓ Updated contract: SE001718 → Type: Energy
# ✓ Updated contract: SE001767 → Type: Energy
# ✓ Updated contract: SE001769 → Type: Energy
# ✓ Updated contract: SE001770 → Type: Energy
# ✓ Updated contract: SE001783 → Type: Energy
# ✓ Updated contract: SE001841 → Type: Energy
# ✓ Updated contract: SE001845 → Type: Energy
# ✓ Updated contract: SE001846 → Type: Energy
# ✓ Updated contract: SE001847 → Type: Energy
# ✓ Updated contract: SE001848 → Type: Energy
# ✓ Updated contract: SE001874 → Type: Energy
# ✓ Updated contract: SE001876 → Type: Energy
# ✓ Updated contract: SE001888 → Type: Energy
# ✓ Updated contract: SE001889 → Type: Energy
# ✓ Updated contract: SE001890 → Type: Energy
# ✓ Updated contract: SE001891 → Type: Energy
# ✓ Updated contract: SE001896 → Type: Energy
# ✓ Updated contract: SE001897 → Type: Energy
# ✓ Updated contract: SE001902 → Type: Energy
# ✓ Updated contract: SE001903 → Type: Energy
# ✓ Updated contract: SE001904 → Type: Energy
# ✓ Updated contract: SE001905 → Type: Energy
# ✓ Updated contract: SE001906 → Type: Energy
# ✓ Updated contract: SE001907 → Type: Energy
# ✓ Updated contract: SE001908 → Type: Energy
# ✓ Updated contract: SE001912 → Type: Energy
# ✓ Updated contract: SE001913 → Type: Energy
# ✓ Updated contract: SE001914 → Type: Energy
# ✓ Updated contract: SE001916 → Type: Energy
# ✓ Updated contract: SE001917 → Type: Energy
# ✓ Updated contract: SE001920 → Type: Energy
# ✓ Updated contract: SE001921 → Type: Energy
# ✓ Updated contract: SE001933 → Type: Energy
# ✓ Updated contract: SE001945 → Type: Energy
# ✓ Updated contract: SE001947 → Type: Energy
# ✓ Updated contract: SE001952 → Type: Energy
# ✓ Updated contract: SE001959 → Type: Energy
# ✓ Updated contract: SE001960 → Type: Energy
# ✓ Updated contract: SE001979 → Type: Energy
# ✓ Updated contract: SE001981 → Type: Energy
# ✓ Updated contract: SE001982 → Type: Energy
# ✓ Updated contract: SE001986 → Type: Energy
# ✓ Updated contract: SE001989 → Type: Energy
# ✓ Updated contract: SE002021 → Type: Energy
# ✓ Updated contract: SE002049 → Type: Energy
# ✓ Updated contract: SE002050 (LGC) → Type: Green
# ✓ Updated contract: SE002051 (LGC) → Type: Green
# ✓ Updated contract: SE002052 (LGC) → Type: Green
# ✓ Updated contract: SE002053 (LGC) → Type: Green
# ✓ Updated contract: SE002054 (LGC) → Type: Green
# ✓ Updated contract: SE002055 (LGC) → Type: Green
# ✓ Updated contract: SE002056 (LGC) → Type: Green
# ✓ Updated contract: SE002057 (LGC) → Type: Green
# ✓ Updated contract: SE002058 (LGC) → Type: Green
# ✓ Updated contract: SE002059 (LGC) → Type: Green
# ✓ Updated contract: SE002060 (LGC) → Type: Green
# ✓ Updated contract: SE002061 (LGC) → Type: Green
# ✓ Updated contract: SE002062 → Type: Energy
# ✓ Updated contract: SE002063 → Type: Energy
# ✓ Updated contract: SE002077 → Type: Energy
# ✓ Updated contract: SE002078 → Type: Energy
# ✓ Updated contract: SE002091 → Type: Energy
# ✓ Updated contract: SE002097 (LGC) → Type: Green
# ✓ Updated contract: SE002103 → Type: Energy
# ✓ Updated contract: SE002105 (LGC) → Type: Green
# ✓ Updated contract: SE002141 → Type: Energy
# ✓ Updated contract: SE002153 → Type: Energy
# ✓ Updated contract: SE002154 → Type: Energy
# ✓ Updated contract: SE002155 → Type: Energy
# ✓ Updated contract: SE002157 → Type: Energy
# ✓ Updated contract: SE002159 (LGC) → Type: Green
# ✓ Updated contract: SE002161 → Type: Energy
# ✓ Updated contract: SE002163 → Type: Energy
# ✓ Updated contract: SE002164 → Type: Energy
# ✓ Updated contract: SE002165 → Type: Energy
# ✓ Updated contract: SE002166 → Type: Energy
# ✓ Updated contract: SE002169 → Type: Energy
# ✓ Updated contract: SE002171 → Type: Energy
# ✓ Updated contract: SE002172 → Type: Energy
# ✓ Updated contract: SE002173 → Type: Energy
# ✓ Updated contract: SE002174 → Type: Energy
# ✓ Updated contract: SE002175 → Type: Energy
# ✓ Updated contract: SE002176 → Type: Energy
# ✓ Updated contract: SE002178 → Type: Energy
# ✓ Updated contract: SE002179 → Type: Energy
# ✓ Updated contract: SE002180 → Type: Energy
# ✓ Updated contract: SE002182 → Type: Energy
# ✓ Updated contract: SE002183 → Type: Energy
# ✓ Updated contract: SE002184 → Type: Energy
# ✓ Updated contract: SE002185 → Type: Energy
# ✓ Updated contract: SE002186 → Type: Energy
# ✓ Updated contract: SE002191 → Type: Energy
# ✓ Updated contract: SE002193 → Type: Energy
# ✓ Updated contract: SE002194 → Type: Energy
# ✓ Updated contract: SE002195 → Type: Energy
# ✓ Updated contract: SE002196 → Type: Energy
# ✓ Updated contract: SE002197 → Type: Energy
# ✓ Updated contract: SE002198 → Type: Energy
# ✓ Updated contract: SE002199 → Type: Energy
# ✓ Updated contract: SE002200 → Type: Energy
# ✓ Updated contract: SE002201 → Type: Energy
# ✓ Updated contract: SE002202 → Type: Energy
# ✓ Updated contract: SE002203 → Type: Energy
# ✓ Updated contract: SE002211 → Type: Energy
# ✓ Updated contract: SE002212 → Type: Energy
# ✓ Updated contract: SE002213 (LGC) → Type: Green
# ✓ Updated contract: SE002214 (LGC) → Type: Green
# ✓ Updated contract: SE002215 (LGC) → Type: Green
# ✓ Updated contract: SE002216 (LGC) → Type: Green
# ✓ Updated contract: SE002217 (LGC) → Type: Green
# ✓ Updated contract: SE002218 (LGC) → Type: Green
# ✓ Updated contract: SE002219 (LGC) → Type: Green
# ✓ Updated contract: SE002220 (LGC) → Type: Green
# ✓ Updated contract: SE002221 (LGC) → Type: Green
# ✓ Updated contract: SE002222 (LGC) → Type: Green
# ✓ Updated contract: SE002223 (LGC) → Type: Green
# ✓ Updated contract: SE002224 (LGC) → Type: Green
# ✓ Updated contract: SE002225 (LGC) → Type: Green
# ✓ Updated contract: SE002226 (LGC) → Type: Green
# ✓ Updated contract: SE002227 (LGC) → Type: Green
# ✓ Updated contract: SE002228 (LGC) → Type: Green
# ✓ Updated contract: SE002229 (LGC) → Type: Green
# ✓ Updated contract: SE002232 → Type: Energy
# ✓ Updated contract: SE002233 → Type: Energy
# ✓ Updated contract: SE002234 → Type: Energy
# ✓ Updated contract: SE002235 → Type: Energy
# ✓ Updated contract: SE002236 → Type: Energy
# ✓ Updated contract: SE002252 (LGC) → Type: Green
# ✓ Updated contract: SE002253 (LGC) → Type: Green
# ✓ Updated contract: SE002254 (LGC) → Type: Green
# ✓ Updated contract: SE002255 → Type: Energy
# ✓ Updated contract: SE002256 → Type: Energy
# ✓ Updated contract: SE002257 → Type: Energy
# ✓ Updated contract: SE002258 → Type: Energy
# ✓ Updated contract: SE002259 → Type: Energy
# ✓ Updated contract: SE002260 → Type: Energy
# ✓ Updated contract: SE002262 (LGC) → Type: Green
# ✓ Updated contract: SE002263 → Type: Energy
# ✓ Updated contract: SE002266 (LGC) → Type: Green
# ✓ Updated contract: SE002267 (LGC) → Type: Green
# ✓ Updated contract: SE002268 → Type: Energy
# ✓ Updated contract: SE002269 → Type: Energy
# ✓ Updated contract: SE002270 (LGC) → Type: Green
# ✓ Updated contract: SE002271 (LGC) → Type: Green
# ✓ Updated contract: SE002272 (LGC) → Type: Green
# ✓ Updated contract: SE002273 (LGC) → Type: Green
# ✓ Updated contract: SE002274 (LGC) → Type: Green
# ✓ Updated contract: SE002275 (LGC) → Type: Green
# ✓ Updated contract: SE002276 (LGC) → Type: Green
# ✓ Updated contract: SE002277 (LGC) → Type: Green
# ✓ Updated contract: SE002278 (LGC) → Type: Green
# ✓ Updated contract: Templers → Type: Energy
# ✓ Updated contract: VIC Retail FY25 B → Type: Energy
# ✓ Updated contract: VIC Retail FY25 Cap B → Type: Energy
# ✓ Updated contract: VIC Retail FY25 Cap S → Type: Energy
# ✓ Updated contract: VIC Retail FY25 S → Type: Energy
# ✓ Updated contract: VIC Solar FY25 B → Type: Energy
# ✓ Updated contract: VIC Solar FY25 Cap B → Type: Energy
# ✓ Updated contract: VIC Solar FY25 Cap S → Type: Energy
# ✓ Updated contract: VIC Solar FY25 S → Type: Energy
# ✓ Updated contract: VIC Wind FY25 B → Type: Energy
# ✓ Updated contract: VIC Wind FY25 Cap B → Type: Energy
# ✓ Updated contract: VIC Wind FY25 Cap S → Type: Energy
# ✓ Updated contract: VIC Wind FY25 S → Type: Energy
#
# ================================================================================
# UPDATE SUMMARY
# ================================================================================
# Successfully updated: 354
# Errors: 0
# Total processed: 354
# 🎉 All contracts updated successfully!
