# %%
import requests
import json
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta
from typing import List, Dict, Any
import calendar

class EndDateTenorUpdater:
    def __init__(self, api_base_url: str = "http://localhost:3000/api/contracts"):
        self.api_base_url = api_base_url
    
    def fetch_all_contracts(self) -> List[Dict[str, Any]]:
        """Fetch all contracts from the database"""
        try:
            response = requests.get(self.api_base_url)
            if response.status_code == 200:
                contracts = response.json()
                print(f"✓ Fetched {len(contracts)} contracts from database")
                return contracts
            else:
                print(f"✗ Error fetching contracts: {response.status_code}")
                return []
        except Exception as e:
            print(f"✗ Error fetching contracts: {e}")
            return []
    
    def get_month_end_date(self, date_str: str) -> str:
        """Convert a date to the last day of that month"""
        try:
            date = datetime.strptime(date_str, '%Y-%m-%d')
            # Get the last day of the month
            last_day = calendar.monthrange(date.year, date.month)[1]
            month_end = datetime(date.year, date.month, last_day)
            return month_end.strftime('%Y-%m-%d')
        except Exception as e:
            print(f"Error converting date {date_str}: {e}")
            return date_str
    
    def calculate_tenor_from_dates(self, start_date: str, end_date: str) -> Dict[str, Any]:
        """Calculate tenor from start and end dates"""
        try:
            start = datetime.strptime(start_date, '%Y-%m-%d')
            end = datetime.strptime(end_date, '%Y-%m-%d')
            
            # Calculate difference in months
            months_diff = (end.year - start.year) * 12 + (end.month - start.month)
            
            # If the end date is at month end and start is at month start, 
            # and days align well, prefer exact month/year calculation
            years = months_diff // 12
            remaining_months = months_diff % 12
            
            # Determine best representation
            if months_diff % 12 == 0 and months_diff >= 12:
                # Even years
                return {
                    'value': years,
                    'unit': 'years'
                }
            elif months_diff < 24:
                # Less than 2 years, show in months
                return {
                    'value': months_diff,
                    'unit': 'months'
                }
            elif remaining_months == 0:
                # Exact years
                return {
                    'value': years,
                    'unit': 'years'
                }
            else:
                # Mixed, show in months for precision
                return {
                    'value': months_diff,
                    'unit': 'months'
                }
        except Exception as e:
            print(f"Error calculating tenor for {start_date} to {end_date}: {e}")
            return {
                'value': 1,
                'unit': 'years'
            }
    
    def update_contract_dates_and_tenor(self, contract: Dict[str, Any]) -> bool:
        """Update a single contract's end date and tenor"""
        try:
            contract_id = contract.get('_id')
            if not contract_id:
                print(f"✗ No ID found for contract: {contract.get('name', 'Unknown')}")
                return False
            
            contract_name = contract.get('name', 'Unknown')
            start_date = contract.get('startDate')
            end_date = contract.get('endDate')
            
            if not start_date or not end_date:
                print(f"⚠️  Missing dates for contract: {contract_name}")
                return False
            
            # Calculate new end date (month end)
            new_end_date = self.get_month_end_date(end_date)
            
            # Calculate tenor from corrected dates
            tenor = self.calculate_tenor_from_dates(start_date, new_end_date)
            
            # Check if updates are needed
            needs_update = False
            update_payload = {'id': contract_id}
            
            if new_end_date != end_date:
                needs_update = True
                update_payload['endDate'] = new_end_date
                print(f"📅 {contract_name}: End date {end_date} → {new_end_date}")
            
            # Always update tenor if not present or if dates changed
            current_tenor = contract.get('tenor', {})
            if (not current_tenor or 
                current_tenor.get('value') != tenor['value'] or 
                current_tenor.get('unit') != tenor['unit'] or
                needs_update):
                needs_update = True
                update_payload['tenor'] = tenor
                print(f"⏱️  {contract_name}: Tenor → {tenor['value']} {tenor['unit']}")
            
            if not needs_update:
                print(f"✓ {contract_name}: No updates needed")
                return True
            
            # Make API call to update contract
            response = requests.put(self.api_base_url, json=update_payload)
            
            if response.status_code == 200:
                print(f"✅ Updated contract: {contract_name}")
                return True
            else:
                print(f"✗ Error updating contract {contract_name}: {response.status_code} - {response.text}")
                return False
                
        except Exception as e:
            print(f"✗ Error updating contract {contract.get('name', 'Unknown')}: {e}")
            return False
    
    def preview_changes(self, contracts: List[Dict[str, Any]]) -> None:
        """Preview what changes will be made"""
        print("\n" + "="*80)
        print("PREVIEW OF CHANGES")
        print("="*80)
        
        end_date_changes = 0
        tenor_updates = 0
        no_changes = 0
        
        for contract in contracts:
            name = contract.get('name', 'Unknown')
            start_date = contract.get('startDate')
            end_date = contract.get('endDate')
            current_tenor = contract.get('tenor', {})
            
            if not start_date or not end_date:
                print(f"⚠️  {name}: Missing start or end date")
                continue
            
            # Calculate what the new values would be
            new_end_date = self.get_month_end_date(end_date)
            new_tenor = self.calculate_tenor_from_dates(start_date, new_end_date)
            
            changes = []
            
            if new_end_date != end_date:
                changes.append(f"End date: {end_date} → {new_end_date}")
                end_date_changes += 1
            
            if (not current_tenor or 
                current_tenor.get('value') != new_tenor['value'] or 
                current_tenor.get('unit') != new_tenor['unit']):
                old_tenor = f"{current_tenor.get('value', 'N/A')} {current_tenor.get('unit', 'N/A')}" if current_tenor else "None"
                changes.append(f"Tenor: {old_tenor} → {new_tenor['value']} {new_tenor['unit']}")
                tenor_updates += 1
            
            if changes:
                print(f"🔄 {name}:")
                for change in changes:
                    print(f"   {change}")
            else:
                no_changes += 1
        
        print(f"\nSummary:")
        print(f"  Contracts needing end date updates: {end_date_changes}")
        print(f"  Contracts needing tenor updates: {tenor_updates}")
        print(f"  Contracts with no changes needed: {no_changes}")
        print(f"  Total contracts: {len(contracts)}")
    
    def update_all_contracts(self, dry_run: bool = True) -> None:
        """Main method to update all contracts with corrected end dates and tenors"""
        print("Starting database end date and tenor correction process...")
        print(f"Mode: {'DRY RUN (preview only)' if dry_run else 'LIVE UPDATE'}")
        
        # Fetch all contracts
        contracts = self.fetch_all_contracts()
        if not contracts:
            print("No contracts found. Exiting.")
            return
        
        # Preview changes
        self.preview_changes(contracts)
        
        if dry_run:
            print(f"\n{'='*80}")
            print("DRY RUN COMPLETE")
            print("="*80)
            print("This was a preview. To execute the updates, run with dry_run=False")
            return
        
        # Confirm before proceeding with live updates
        print(f"\n{'='*80}")
        print("READY TO EXECUTE LIVE UPDATES")
        print("="*80)
        confirm = input("Are you sure you want to proceed? (y/N): ").strip().lower()
        
        if confirm != 'y':
            print("Update cancelled.")
            return
        
        # Execute updates
        print("\nExecuting updates...")
        success_count = 0
        error_count = 0
        
        for contract in contracts:
            if self.update_contract_dates_and_tenor(contract):
                success_count += 1
            else:
                error_count += 1
        
        # Final summary
        print(f"\n{'='*80}")
        print("UPDATE SUMMARY")
        print("="*80)
        print(f"Successfully updated: {success_count}")
        print(f"Errors: {error_count}")
        print(f"Total processed: {len(contracts)}")
        
        if error_count == 0:
            print("🎉 All contracts updated successfully!")
        else:
            print(f"⚠️  {error_count} contracts had errors during update")

# Example usage and test cases
def test_date_calculations():
    """Test the date calculation functions"""
    updater = EndDateTenorUpdater()
    
    print("Testing date calculations:")
    print("="*50)
    
    test_cases = [
        ("2025-01-01", "2025-12-01"),  # Should become 2025-12-31, 1 year
        ("2025-01-01", "2026-01-01"),  # Should become 2026-01-31, 1 year 1 month  
        ("2025-06-01", "2025-06-01"),  # Should become 2025-06-30, 0 months
        ("2025-01-15", "2027-01-15"),  # Should become 2027-01-31, 2 years
        ("2025-03-01", "2025-09-01"),  # Should become 2025-09-30, 6 months
    ]
    
    for start, end in test_cases:
        new_end = updater.get_month_end_date(end)
        tenor = updater.calculate_tenor_from_dates(start, new_end)
        print(f"Start: {start}, End: {end} → {new_end}, Tenor: {tenor['value']} {tenor['unit']}")

if __name__ == "__main__":
    # Test the calculations first
    test_date_calculations()
    
    print("\n" + "="*80)
    print("STARTING CONTRACT DATABASE UPDATE")
    print("="*80)
    
    updater = EndDateTenorUpdater("http://localhost:3000/api/contracts")
    
    # First run a dry run to preview changes
    print("=== DRY RUN: Preview Changes ===")
    updater.update_all_contracts(dry_run=False)
    
    # Uncomment the line below to execute the actual updates
    # print("\n=== LIVE UPDATE: Execute Changes ===")
    # updater.update_all_contracts(dry_run=False)
# Out:
# Testing date calculations:
# ==================================================
# Start: 2025-01-01, End: 2025-12-01 → 2025-12-31, Tenor: 11 months
# Start: 2025-01-01, End: 2026-01-01 → 2026-01-31, Tenor: 1 years
# Start: 2025-06-01, End: 2025-06-01 → 2025-06-30, Tenor: 0 months
# Start: 2025-01-15, End: 2027-01-15 → 2027-01-31, Tenor: 2 years
# Start: 2025-03-01, End: 2025-09-01 → 2025-09-30, Tenor: 6 months
#
# ================================================================================
# STARTING CONTRACT DATABASE UPDATE
# ================================================================================
# === DRY RUN: Preview Changes ===
# Starting database end date and tenor correction process...
# Mode: DRY RUN (preview only)
# ✓ Fetched 354 contracts from database
#
# ================================================================================
# PREVIEW OF CHANGES
# ================================================================================
# 🔄 BVC TOU:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 BVC TOU (LGC):
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 CSIRO TOU:
#    End date: 2030-06-01 → 2030-06-30
#    Tenor: None → 63 months
# 🔄 CSIRO TOU (LGC):
#    End date: 2030-06-01 → 2030-06-30
#    Tenor: None → 63 months
# 🔄 Fairfield Non-TOU:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 Fairfield Non-TOU (LGC):
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 Fairfield TOU:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 Fairfield TOU (LGC):
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 SBS TOU:
#    End date: 2034-06-01 → 2034-06-30
#    Tenor: None → 111 months
# 🔄 SBS TOU (LGC):
#    End date: 2034-06-01 → 2034-06-30
#    Tenor: None → 111 months
# 🔄 SSROC Non-TOU:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 SSROC Non-TOU (LGC):
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 SSROC TOU:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 SSROC TOU (LGC):
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 ISPT TOU:
#    End date: 2030-12-01 → 2030-12-31
#    Tenor: None → 69 months
# 🔄 ISPT TOU (LGC):
#    End date: 2030-12-01 → 2030-12-31
#    Tenor: None → 69 months
# 🔄 Adelaide Metro Non-TOU:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 Adelaide Metro Non-TOU (LGC):
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 Adelaide Metro TOU:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 Adelaide Metro TOU (LGC):
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 Bunnings TOU:
#    End date: 2027-06-01 → 2027-06-30
#    Tenor: None → 27 months
# 🔄 Bunnings TOU (LGC):
#    End date: 2027-06-01 → 2027-06-30
#    Tenor: None → 27 months
# 🔄 CBUS TOU:
#    End date: 2025-08-01 → 2025-08-31
#    Tenor: None → 5 months
# 🔄 CBUS TOU (LGC):
#    End date: 2025-08-01 → 2025-08-31
#    Tenor: None → 5 months
# 🔄 Hentley Farm TOU:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 Hentley Farm TOU (LGC):
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 KMART&TARGET TOU:
#    End date: 2029-12-01 → 2029-12-31
#    Tenor: None → 57 months
# 🔄 KMART&TARGET TOU (LGC):
#    End date: 2029-12-01 → 2029-12-31
#    Tenor: None → 57 months
# 🔄 SA Government Non-TOU:
#    End date: 2031-01-01 → 2031-01-31
#    Tenor: None → 70 months
# 🔄 SA Government Non-TOU (LGC):
#    End date: 2030-12-01 → 2030-12-31
#    Tenor: None → 69 months
# 🔄 SACOME TOU:
#    End date: 2027-06-01 → 2027-06-30
#    Tenor: None → 27 months
# 🔄 SACOME TOU (LGC):
#    End date: 2027-06-01 → 2027-06-30
#    Tenor: None → 27 months
# 🔄 Sarstedt TOU:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 Sarstedt TOU (LGC):
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 Sekisui TOU:
#    End date: 2027-12-01 → 2027-12-31
#    Tenor: None → 33 months
# 🔄 Sekisui TOU (LGC):
#    End date: 2027-12-01 → 2027-12-31
#    Tenor: None → 33 months
# 🔄 St John Ambulance Non-TOU:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 St John Ambulance Non-TOU (LGC):
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 Sundrop Farms TOU:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 Sundrop Farms TOU (LGC):
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 Kings The Printer TOU:
#    End date: 2028-02-01 → 2028-02-29
#    Tenor: None → 35 months
# 🔄 SEEK TOU:
#    End date: 2030-12-01 → 2030-12-31
#    Tenor: None → 69 months
# 🔄 SEEK TOU (LGC):
#    End date: 2030-12-01 → 2030-12-31
#    Tenor: None → 69 months
# 🔄 Villa Maria TOU:
#    End date: 2027-12-01 → 2027-12-31
#    Tenor: None → 33 months
# 🔄 Villa Maria TOU (LGC):
#    End date: 2027-12-01 → 2027-12-31
#    Tenor: None → 33 months
# 🔄 Blue Grass Solar 202203:
#    End date: 2032-12-01 → 2032-12-31
#    Tenor: None → 93 months
# 🔄 Blue Grass Solar 202203 (LGC):
#    End date: 2032-12-01 → 2032-12-31
#    Tenor: None → 93 months
# 🔄 Cathedral Rocks Wind 202408:
#    End date: 2034-06-01 → 2034-06-30
#    Tenor: None → 111 months
# 🔄 Cathedral Rocks Wind 202408 (LGC):
#    End date: 2034-06-01 → 2034-06-30
#    Tenor: None → 111 months
# 🔄 Collector Wind 202403:
#    End date: 2034-03-01 → 2034-03-31
#    Tenor: None → 9 years
# 🔄 Collector Wind 202403 (LGC):
#    End date: 2034-03-01 → 2034-03-31
#    Tenor: None → 9 years
# 🔄 Diapur Wind 202212:
#    End date: 2032-12-01 → 2032-12-31
#    Tenor: None → 93 months
# 🔄 Diapur Wind 202212 (LGC):
#    End date: 2032-12-01 → 2032-12-31
#    Tenor: None → 93 months
# 🔄 Edenvale Solar 202411:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 Ferguson Wind 202212:
#    End date: 2032-12-01 → 2032-12-31
#    Tenor: None → 93 months
# 🔄 Ferguson Wind 202212 (LGC):
#    End date: 2032-12-01 → 2032-12-31
#    Tenor: None → 93 months
# 🔄 Ginan Solar 202406:
#    End date: 2028-03-01 → 2028-03-31
#    Tenor: None → 3 years
# 🔄 Ginan Solar 202406 (LGC):
#    End date: 2028-03-01 → 2028-03-31
#    Tenor: None → 3 years
# 🔄 Gunnedah Solar 202407:
#    End date: 2030-04-01 → 2030-04-30
#    Tenor: None → 5 years
# 🔄 Hay Solar 202409:
#    End date: 2030-05-01 → 2030-05-31
#    Tenor: None → 59 months
# 🔄 Hillston 1 Solar 202409:
#    End date: 2030-06-01 → 2030-06-30
#    Tenor: None → 5 years
# 🔄 Hillston 2 Solar 202409:
#    End date: 2030-08-01 → 2030-08-31
#    Tenor: None → 62 months
# 🔄 Kerang Solar 202408:
#    End date: 2035-02-01 → 2035-02-28
#    Tenor: None → 119 months
# 🔄 Kerang Solar 202408 (LGC):
#    End date: 2035-02-01 → 2035-02-28
#    Tenor: None → 119 months
# 🔄 Kootingal Solar 202407:
#    End date: 2030-01-01 → 2030-01-31
#    Tenor: None → 58 months
# 🔄 Moree Solar 202202:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 Moree Solar 202202 (LGC):
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 Mortons Lane Wind 202212:
#    End date: 2032-12-01 → 2032-12-31
#    Tenor: None → 93 months
# 🔄 Mortons Lane Wind 202212 (LGC):
#    End date: 2032-12-01 → 2032-12-31
#    Tenor: None → 93 months
# 🔄 Mulwala Solar 202209:
#    End date: 2033-09-01 → 2033-09-30
#    Tenor: None → 102 months
# 🔄 Mulwala Solar 202209 (LGC):
#    End date: 2033-09-01 → 2033-09-30
#    Tenor: None → 102 months
# 🔄 New England Solar 202412:
#    End date: 2035-06-01 → 2035-06-30
#    Tenor: None → 123 months
# 🔄 New England Solar 202412 (LGC):
#    End date: 2035-06-01 → 2035-06-30
#    Tenor: None → 123 months
# 🔄 Numurkah Solar 201810:
#    End date: 2034-06-01 → 2034-06-30
#    Tenor: None → 111 months
# 🔄 Numurkah Solar 201810 (LGC):
#    End date: 2034-06-01 → 2034-06-30
#    Tenor: None → 111 months
# 🔄 Numurkah Solar 202410:
#    End date: 2029-12-01 → 2029-12-31
#    Tenor: None → 57 months
# 🔄 Numurkah Solar 202410 (LGC):
#    End date: 2029-12-01 → 2029-12-31
#    Tenor: None → 57 months
# 🔄 Nyngan Solar 202212:
#    End date: 2033-12-01 → 2033-12-31
#    Tenor: None → 105 months
# 🔄 Nyngan Solar 202212 (LGC):
#    End date: 2033-12-01 → 2033-12-31
#    Tenor: None → 105 months
# 🔄 Quorn Solar 202406:
#    End date: 2036-06-01 → 2036-06-30
#    Tenor: None → 119 months
# 🔄 Quorn Solar 202406 (LGC):
#    End date: 2036-06-01 → 2036-06-30
#    Tenor: None → 119 months
# 🔄 Renmark Solar 202212:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 Starfish Hill Wind 202403:
#    End date: 2034-03-01 → 2034-03-31
#    Tenor: None → 9 years
# 🔄 Starfish Hill Wind 202403 (LGC):
#    End date: 2034-03-01 → 2034-03-31
#    Tenor: None → 9 years
# 🔄 Tailem Bend 2 Solar 202203:
#    End date: 2038-06-01 → 2038-06-30
#    Tenor: None → 159 months
# 🔄 Temora Solar 202407:
#    End date: 2029-12-01 → 2029-12-31
#    Tenor: None → 57 months
# 🔄 Wagga Wagga Solar 202303:
#    End date: 2033-07-01 → 2033-07-31
#    Tenor: None → 100 months
# 🔄 Wagga Wagga Solar 202303 (LGC):
#    End date: 2033-07-01 → 2033-07-31
#    Tenor: None → 100 months
# 🔄 Waubra Wind 202208:
#    End date: 2032-06-01 → 2032-06-30
#    Tenor: None → 87 months
# 🔄 Waubra Wind 202208 (LGC):
#    End date: 2032-06-01 → 2032-06-30
#    Tenor: None → 87 months
# 🔄 Waubra Wind 202401:
#    End date: 2032-06-01 → 2032-06-30
#    Tenor: None → 87 months
# 🔄 Waubra Wind 202401 (LGC):
#    End date: 2032-06-01 → 2032-06-30
#    Tenor: None → 77 months
# 🔄 Wemen Solar 201806:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 Wemen Solar 201806 (LGC):
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 21 months
# 🔄 Woods Point Solar 202304:
#    End date: 2026-03-01 → 2026-03-31
#    Tenor: None → 1 years
# 🔄 NSW Retail FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Retail FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Retail FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Retail FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Solar FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Solar FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Solar FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Solar FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Wind FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Wind FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Wind FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 NSW Wind FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 QLD Retail FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 QLD Retail FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 QLD Solar FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 QLD Solar FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 QLD Solar FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 QLD Solar FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Retail FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Retail FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Retail FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Retail FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Solar FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Solar FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Solar FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Solar FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Wind FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Wind FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Wind FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SA Wind FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE000352:
#    End date: 2027-06-01 → 2027-06-30
#    Tenor: None → 27 months
# 🔄 SE000354:
#    End date: 2029-12-01 → 2029-12-31
#    Tenor: None → 57 months
# 🔄 SE000780 (LGC):
#    End date: 2025-08-01 → 2025-08-31
#    Tenor: None → 0 months
# 🔄 SE000960 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001052 (LGC):
#    End date: 2026-01-01 → 2026-01-31
#    Tenor: None → 0 months
# 🔄 SE001062:
#    End date: 2029-12-01 → 2029-12-31
#    Tenor: None → 57 months
# 🔄 SE001063:
#    End date: 2029-12-01 → 2029-12-31
#    Tenor: None → 57 months
# 🔄 SE001088:
#    End date: 2038-06-01 → 2038-06-30
#    Tenor: None → 159 months
# 🔄 SE001089:
#    End date: 2038-06-01 → 2038-06-30
#    Tenor: None → 159 months
# 🔄 SE001106 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001139 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001191 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001194:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001272 (LGC):
#    End date: 2027-02-01 → 2027-02-28
#    Tenor: None → 0 months
# 🔄 SE001282 (LGC):
#    End date: 2027-02-01 → 2027-02-28
#    Tenor: None → 0 months
# 🔄 SE001317 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001327:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001350 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001368 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001369:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001392 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001399 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001416 (LGC):
#    End date: 2027-02-01 → 2027-02-28
#    Tenor: None → 0 months
# 🔄 SE001447:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001449:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001452:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001453:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001455:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001470:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001479:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001480 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001482 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001490:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001494:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001498 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001513:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001514:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001515 (LGC):
#    End date: 2027-02-01 → 2027-02-28
#    Tenor: None → 0 months
# 🔄 SE001516:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 SE001517:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001523 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001541 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001547:
#    End date: 2026-06-01 → 2026-06-30
#    Tenor: None → 11 months
# 🔄 SE001550 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001551 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001573:
#    End date: 2026-03-01 → 2026-03-31
#    Tenor: None → 2 months
# 🔄 SE001574 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001575 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001578 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001593 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001600 (LGC):
#    End date: 2027-02-01 → 2027-02-28
#    Tenor: None → 0 months
# 🔄 SE001620:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001628 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001629 (LGC):
#    End date: 2027-02-01 → 2027-02-28
#    Tenor: None → 0 months
# 🔄 SE001639 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001641 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001642:
#    End date: 2026-06-01 → 2026-06-30
#    Tenor: None → 15 months
# 🔄 SE001646:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 SE001648:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 SE001660 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE001677:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001679:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 9 months
# 🔄 SE001685:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001709:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 11 months
# 🔄 SE001712:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001718:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 SE001767:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001769:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001770:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001783:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001841:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001845:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001846:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001847:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001848:
#    End date: 2025-09-01 → 2025-09-30
#    Tenor: None → 2 months
# 🔄 SE001874:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001876:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001888:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001889:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001890:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001891:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001896:
#    End date: 2025-09-01 → 2025-09-30
#    Tenor: None → 2 months
# 🔄 SE001897:
#    End date: 2025-09-01 → 2025-09-30
#    Tenor: None → 2 months
# 🔄 SE001902:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001903:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001904:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001905:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001906:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001907:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001908:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001912:
#    End date: 2026-09-01 → 2026-09-30
#    Tenor: None → 2 months
# 🔄 SE001913:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 2 months
# 🔄 SE001914:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001916:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001917:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001920:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001921:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001933:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001945:
#    End date: 2026-06-01 → 2026-06-30
#    Tenor: None → 2 months
# 🔄 SE001947:
#    End date: 2026-03-01 → 2026-03-31
#    Tenor: None → 2 months
# 🔄 SE001952:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE001959:
#    End date: 2025-09-01 → 2025-09-30
#    Tenor: None → 2 months
# 🔄 SE001960:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001979:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001981:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001982:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001986:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE001989:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002021:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002049:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002050 (LGC):
#    End date: 2025-04-01 → 2025-04-30
#    Tenor: None → 0 months
# 🔄 SE002051 (LGC):
#    End date: 2025-07-01 → 2025-07-31
#    Tenor: None → 0 months
# 🔄 SE002052 (LGC):
#    End date: 2025-10-01 → 2025-10-31
#    Tenor: None → 0 months
# 🔄 SE002053 (LGC):
#    End date: 2026-01-01 → 2026-01-31
#    Tenor: None → 0 months
# 🔄 SE002054 (LGC):
#    End date: 2026-04-01 → 2026-04-30
#    Tenor: None → 0 months
# 🔄 SE002055 (LGC):
#    End date: 2026-07-01 → 2026-07-31
#    Tenor: None → 0 months
# 🔄 SE002056 (LGC):
#    End date: 2026-10-01 → 2026-10-31
#    Tenor: None → 0 months
# 🔄 SE002057 (LGC):
#    End date: 2027-01-01 → 2027-01-31
#    Tenor: None → 0 months
# 🔄 SE002058 (LGC):
#    End date: 2027-04-01 → 2027-04-30
#    Tenor: None → 0 months
# 🔄 SE002059 (LGC):
#    End date: 2027-07-01 → 2027-07-31
#    Tenor: None → 0 months
# 🔄 SE002060 (LGC):
#    End date: 2027-10-01 → 2027-10-31
#    Tenor: None → 0 months
# 🔄 SE002061 (LGC):
#    End date: 2028-01-01 → 2028-01-31
#    Tenor: None → 0 months
# 🔄 SE002062:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002063:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002077:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002078:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002091:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002097 (LGC):
#    End date: 2027-02-01 → 2027-02-28
#    Tenor: None → 0 months
# 🔄 SE002103:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002105 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE002141:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002153:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002154:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002155:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002157:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002159 (LGC):
#    End date: 2027-02-01 → 2027-02-28
#    Tenor: None → 0 months
# 🔄 SE002161:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002163:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002164:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002165:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002166:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002169:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002171:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002172:
#    End date: 2025-09-01 → 2025-09-30
#    Tenor: None → 2 months
# 🔄 SE002173:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 2 months
# 🔄 SE002174:
#    End date: 2026-03-01 → 2026-03-31
#    Tenor: None → 2 months
# 🔄 SE002175:
#    End date: 2026-06-01 → 2026-06-30
#    Tenor: None → 2 months
# 🔄 SE002176:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002178:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002179:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002180:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002182:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002183:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002184:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002185:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002186:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002191:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002193:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002194:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002195:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002196:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002197:
#    End date: 2025-09-01 → 2025-09-30
#    Tenor: None → 2 months
# 🔄 SE002198:
#    End date: 2025-12-01 → 2025-12-31
#    Tenor: None → 2 months
# 🔄 SE002199:
#    End date: 2026-03-01 → 2026-03-31
#    Tenor: None → 2 months
# 🔄 SE002200:
#    End date: 2026-06-01 → 2026-06-30
#    Tenor: None → 2 months
# 🔄 SE002201:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002202:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002203:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002211:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 11 months
# 🔄 SE002212:
#    End date: 2026-12-01 → 2026-12-31
#    Tenor: None → 11 months
# 🔄 SE002213 (LGC):
#    End date: 2026-04-01 → 2026-04-30
#    Tenor: None → 0 months
# 🔄 SE002214 (LGC):
#    End date: 2026-07-01 → 2026-07-31
#    Tenor: None → 0 months
# 🔄 SE002215 (LGC):
#    End date: 2026-10-01 → 2026-10-31
#    Tenor: None → 0 months
# 🔄 SE002216 (LGC):
#    End date: 2027-01-01 → 2027-01-31
#    Tenor: None → 0 months
# 🔄 SE002217 (LGC):
#    End date: 2027-04-01 → 2027-04-30
#    Tenor: None → 0 months
# 🔄 SE002218 (LGC):
#    End date: 2027-07-01 → 2027-07-31
#    Tenor: None → 0 months
# 🔄 SE002219 (LGC):
#    End date: 2027-10-01 → 2027-10-31
#    Tenor: None → 0 months
# 🔄 SE002220 (LGC):
#    End date: 2028-01-01 → 2028-01-31
#    Tenor: None → 0 months
# 🔄 SE002221 (LGC):
#    End date: 2028-04-01 → 2028-04-30
#    Tenor: None → 0 months
# 🔄 SE002222 (LGC):
#    End date: 2028-07-01 → 2028-07-31
#    Tenor: None → 0 months
# 🔄 SE002223 (LGC):
#    End date: 2028-10-01 → 2028-10-31
#    Tenor: None → 0 months
# 🔄 SE002224 (LGC):
#    End date: 2029-01-01 → 2029-01-31
#    Tenor: None → 0 months
# 🔄 SE002225 (LGC):
#    End date: 2029-04-01 → 2029-04-30
#    Tenor: None → 0 months
# 🔄 SE002226 (LGC):
#    End date: 2029-07-01 → 2029-07-31
#    Tenor: None → 0 months
# 🔄 SE002227 (LGC):
#    End date: 2029-10-01 → 2029-10-31
#    Tenor: None → 0 months
# 🔄 SE002228 (LGC):
#    End date: 2030-01-01 → 2030-01-31
#    Tenor: None → 0 months
# 🔄 SE002229 (LGC):
#    End date: 2030-04-01 → 2030-04-30
#    Tenor: None → 0 months
# 🔄 SE002232:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002233:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002234:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002235:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002236:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002252 (LGC):
#    End date: 2030-07-01 → 2030-07-31
#    Tenor: None → 0 months
# 🔄 SE002253 (LGC):
#    End date: 2030-10-01 → 2030-10-31
#    Tenor: None → 0 months
# 🔄 SE002254 (LGC):
#    End date: 2031-01-01 → 2031-01-31
#    Tenor: None → 0 months
# 🔄 SE002255:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002256:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002257:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002258:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002259:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002260:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002262 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE002263:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 2 months
# 🔄 SE002266 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002267 (LGC):
#    End date: 2026-02-01 → 2026-02-28
#    Tenor: None → 0 months
# 🔄 SE002268:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002269:
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002270 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002271 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002272 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002273 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002274 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002275 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002276 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002277 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 SE002278 (LGC):
#    End date: 2025-03-01 → 2025-03-31
#    Tenor: None → 0 months
# 🔄 Templers:
#    End date: 2045-06-29 → 2045-06-30
# 🔄 VIC Retail FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Retail FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Retail FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Retail FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Solar FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Solar FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Solar FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Solar FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Wind FY25 B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Wind FY25 Cap B:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Wind FY25 Cap S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
# 🔄 VIC Wind FY25 S:
#    End date: 2025-06-01 → 2025-06-30
#    Tenor: None → 3 months
#
# Summary:
#   Contracts needing end date updates: 354
#   Contracts needing tenor updates: 353
#   Contracts with no changes needed: 0
#   Total contracts: 354
#
# ================================================================================
# DRY RUN COMPLETE
# ================================================================================
# This was a preview. To execute the updates, run with dry_run=False
