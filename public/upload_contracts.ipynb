# %%
import pandas as pd
import requests
import json
from datetime import datetime, timedelta
from typing import Dict, List, Any
import re
import calendar

class ContractDataImporter:
    def __init__(self, api_base_url: str = "http://localhost:3000/api/contracts"):
        self.api_base_url = api_base_url
        self.contracts_cache = {}
        
    def load_csv(self, filepath: str) -> pd.DataFrame:
        """Load and parse the CSV file"""
        try:
            df = pd.read_csv(filepath)
            print(f"Loaded CSV with {len(df)} rows and columns: {list(df.columns)}")
            return df
        except Exception as e:
            print(f"Error loading CSV: {e}")
            return None
    
    def clean_and_validate_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """Clean and validate the CSV data"""
        # Clean column names by stripping whitespace
        df.columns = df.columns.str.strip()
        
        # Print actual columns for debugging
        print(f"Actual CSV columns (after cleaning): {list(df.columns)}")
        
        # Map columns to find the right ones
        column_mapping = {}
        
        # Find Volume column (could have spaces or be at the end)
        volume_cols = [col for col in df.columns if 'volume' in col.lower() and 'cy' not in col.lower()]
        if volume_cols:
            column_mapping['Volume'] = volume_cols[0]
            print(f"Found Volume column: '{volume_cols[0]}'")
        
        # Find other columns
        required_base_columns = ['New_deal_name', 'State', 'type', 'Year', 'Month', 'Price_CY']
        
        for req_col in required_base_columns:
            matching_cols = [col for col in df.columns if req_col.lower() == col.lower()]
            if matching_cols:
                column_mapping[req_col] = matching_cols[0]
            else:
                print(f"Warning: Could not find column matching '{req_col}'")
        
        # Check if we found all required columns
        required_columns = ['New_deal_name', 'State', 'type', 'Year', 'Month', 'Volume', 'Price_CY']
        missing_cols = [col for col in required_columns if col not in column_mapping]
        
        if missing_cols:
            print(f"Missing columns after mapping: {missing_cols}")
            # Try to find similar column names for missing columns
            for missing_col in missing_cols:
                similar_cols = [col for col in df.columns if missing_col.lower() in col.lower()]
                if similar_cols:
                    print(f"  Similar columns found for '{missing_col}': {similar_cols}")
                    # Auto-map if there's only one similar column
                    if len(similar_cols) == 1:
                        column_mapping[missing_col] = similar_cols[0]
                        print(f"    Auto-mapped '{missing_col}' to '{similar_cols[0]}'")
            
            # Check again after auto-mapping
            missing_cols = [col for col in required_columns if col not in column_mapping]
            if missing_cols:
                print(f"Still missing columns: {missing_cols}")
                return pd.DataFrame()  # Return empty dataframe if critical columns missing
        
        # Clean data
        df_clean = df.copy()
        
        # Rename columns to standard names for easier processing
        df_clean = df_clean.rename(columns={v: k for k, v in column_mapping.items()})
        
        # Convert Volume to numeric, handling commas and dashes
        if 'Volume' in df_clean.columns:
            print(f"Processing Volume column...")
            df_clean['Volume'] = df_clean['Volume'].astype(str).str.replace(',', '').str.replace('-', '0').str.strip()
            df_clean['Volume'] = pd.to_numeric(df_clean['Volume'], errors='coerce').fillna(0)
            print(f"Sample Volume data: {df_clean['Volume'].head().tolist()}")
        
        # Convert Price_CY to numeric
        if 'Price_CY' in df_clean.columns:
            df_clean['Price_CY'] = df_clean['Price_CY'].astype(str).str.replace(',', '').str.strip()
            df_clean['Price_CY'] = pd.to_numeric(df_clean['Price_CY'], errors='coerce').fillna(0)
        
        # Remove rows with missing deal names
        df_clean = df_clean.dropna(subset=['New_deal_name'])
        
        print(f"Cleaned data: {len(df_clean)} rows remaining")
        return df_clean
    
    def parse_date_from_row(self, row) -> str:
        """Parse date from Year and Month columns"""
        try:
            year = int(row['Year'])
            month = int(row['Month'])
            # Create first day of the month as timestamp
            date = datetime(year, month, 1)
            return date.isoformat()
        except:
            return datetime.now().isoformat()
    
    def get_hours_in_period(self, year: int, month: int) -> int:
        """Get the number of hours in a given month"""
        days_in_month = calendar.monthrange(year, month)[1]
        return days_in_month * 24
    
    def convert_volume_for_contract_type(self, volume_mwh: float, contract_type: str, year: int, month: int) -> float:
        """Convert MWh to appropriate unit based on contract type"""
        if contract_type == 'wholesale':
            # Convert MWh to MW by dividing by hours in the period
            hours_in_period = self.get_hours_in_period(year, month)
            volume_mw = volume_mwh / hours_in_period
            return round(volume_mw, 3)  # Round to 3 decimal places for MW
        else:
            # Retail and offtake contracts keep MWh
            return round(volume_mwh, 0)  # Round to whole MWh
    
    def get_volume_unit(self, contract_type: str) -> str:
        """Get the appropriate volume unit based on contract type"""
        if contract_type == 'wholesale':
            return 'MW'
        else:
            return 'MWh'
    
    def map_contract_type(self, csv_type: str) -> str:
        """Map CSV type to contract type"""
        type_mapping = {
            'Retail': 'retail',
            'Wholesale': 'wholesale', 
            'Offtake': 'offtake'
        }
        return type_mapping.get(csv_type, 'retail')
    
    def map_contract_category(self, contract_type: str, deal_name: str, sub_type: str = None) -> str:
        """Determine contract category based on type, deal name, and sub_type"""
        if contract_type == 'retail':
            if 'Government' in deal_name or 'Gov' in deal_name:
                return 'Government Customer'
            elif 'Industrial' in deal_name or 'Mining' in deal_name:
                return 'Industrial Customer'
            else:
                return 'Retail Customer'
        elif contract_type == 'wholesale':
            # Use Sub_Type for wholesale contracts
            if sub_type and sub_type.strip():
                return sub_type.strip()
            else:
                return 'Swap'  # Default fallback
        else:  # offtake
            if 'Solar' in deal_name:
                return 'Solar Farm'
            elif 'Wind' in deal_name:
                return 'Wind Farm'
            else:
                return 'Solar Farm'
    
    def group_data_by_contract(self, df: pd.DataFrame) -> Dict[str, List[Dict]]:
        """Group data by unique deal name (aggregating all years) and unit type"""
        contracts_data = {}
        
        for _, row in df.iterrows():
            deal_name = row['New_deal_name']
            year = row['Year']
            unit = row.get('Unit', 'Energy')  # Default to Energy if Unit column not found
            sub_type = row.get('Sub_Type', '')  # Get Sub_Type for wholesale contracts
            contract_type = self.map_contract_type(row['type'])
            
            # Create unique key for contract (deal name + unit type)
            contract_key = f"{deal_name}_{unit}"
            
            if contract_key not in contracts_data:
                contracts_data[contract_key] = {
                    'deal_name': deal_name,
                    'unit': unit,
                    'sub_type': sub_type,
                    'state': row['State'],
                    'type': contract_type,
                    'buysell': row.get('buysell', 'Sell'),
                    'time_series_data': [],
                    'years_covered': set(),
                    'contract_info': {
                        'start_date': row.get('Start', ''),
                        'end_date': row.get('End', ''),
                        'time': row.get('Time', '')
                    }
                }
            
            # Add year to covered years
            contracts_data[contract_key]['years_covered'].add(year)
            
            # Convert volume based on contract type
            original_volume_mwh = float(row['Volume'])
            converted_volume = self.convert_volume_for_contract_type(
                original_volume_mwh, contract_type, year, row['Month']
            )
            
            # Add time series point
            timestamp = self.parse_date_from_row(row)
            period = f"{year}-{str(row['Month']).zfill(2)}"
            
            time_point = {
                'timestamp': timestamp,
                'volume': converted_volume,
                'price': round(float(row['Price_CY']), 2),  # Round to 2 decimal places
                'period': period,
                'periodType': 'monthly'
            }
            
            contracts_data[contract_key]['time_series_data'].append(time_point)
        
        # Convert years_covered set to sorted list for better display
        for contract_key in contracts_data:
            years_list = sorted(list(contracts_data[contract_key]['years_covered']))
            contracts_data[contract_key]['years_covered'] = years_list
            volume_unit = self.get_volume_unit(contracts_data[contract_key]['type'])
            print(f"Contract: {contracts_data[contract_key]['deal_name']} ({contracts_data[contract_key]['unit']}) - Type: {contracts_data[contract_key]['type']} - Unit: {volume_unit} - Years: {years_list}")
        
        print(f"Grouped data into {len(contracts_data)} unique contracts")
        return contracts_data
    
    def calculate_annual_volume(self, time_series: List[Dict], years_covered: List[int], contract_type: str) -> float:
        """Calculate volume for one full calendar year if data exists, otherwise return total"""
        if not time_series:
            return 0
        
        # Group time series by year
        yearly_volumes = {}
        for point in time_series:
            timestamp = datetime.fromisoformat(point['timestamp'])
            year = timestamp.year
            
            if year not in yearly_volumes:
                yearly_volumes[year] = {'volume': 0, 'months': set()}
            
            yearly_volumes[year]['volume'] += point['volume']
            yearly_volumes[year]['months'].add(timestamp.month)
        
        # Check if we have any complete year (12 months of data)
        complete_years = []
        for year, data in yearly_volumes.items():
            if len(data['months']) == 12:  # Full calendar year
                complete_years.append((year, data['volume']))
        
        if complete_years:
            # Return volume from the most recent complete year
            complete_years.sort(key=lambda x: x[0], reverse=True)  # Sort by year, newest first
            volume = complete_years[0][1]
        else:
            # No complete year found, return total volume for all available data
            volume = sum(point['volume'] for point in time_series)
        
        # Round appropriately based on contract type
        if contract_type == 'wholesale':
            return round(volume, 3)  # MW to 3 decimal places
        else:
            return round(volume, 0)  # MWh to whole numbers
    
    def clear_database(self) -> bool:
        """Clear all contracts from the database"""
        try:
            # First fetch all contracts to get their IDs
            response = requests.get(self.api_base_url)
            if response.status_code != 200:
                print(f"Error fetching contracts for deletion: {response.status_code}")
                return False
            
            contracts = response.json()
            print(f"Found {len(contracts)} contracts to delete...")
            
            deleted_count = 0
            error_count = 0
            
            for contract in contracts:
                contract_id = contract.get('_id') or contract.get('id')
                if contract_id:
                    try:
                        delete_response = requests.delete(f"{self.api_base_url}?id={contract_id}")
                        if delete_response.status_code == 200:
                            deleted_count += 1
                            print(f"  ✓ Deleted: {contract.get('name', 'Unknown')}")
                        else:
                            error_count += 1
                            print(f"  ✗ Error deleting {contract.get('name', 'Unknown')}: {delete_response.status_code}")
                    except Exception as e:
                        error_count += 1
                        print(f"  ✗ Error deleting {contract.get('name', 'Unknown')}: {e}")
                else:
                    error_count += 1
                    print(f"  ✗ No ID found for contract: {contract.get('name', 'Unknown')}")
            
            print(f"\nDatabase clearing summary:")
            print(f"  Deleted: {deleted_count}")
            print(f"  Errors: {error_count}")
            print(f"  Total processed: {len(contracts)}")
            
            return error_count == 0
            
        except Exception as e:
            print(f"Error clearing database: {e}")
            return False
    
    def fetch_existing_contracts(self) -> List[Dict]:
        """Fetch existing contracts from API"""
        try:
            response = requests.get(self.api_base_url)
            if response.status_code == 200:
                contracts = response.json()
                print(f"Fetched {len(contracts)} existing contracts")
                return contracts
            else:
                print(f"Error fetching contracts: {response.status_code}")
                return []
        except Exception as e:
            print(f"Error fetching contracts: {e}")
            return []
    
    def find_matching_contract(self, deal_name: str, existing_contracts: List[Dict]) -> Dict:
        """Find existing contract that matches the deal name"""
        for contract in existing_contracts:
            if contract['name'].lower() == deal_name.lower():
                return contract
        return None
    
    def create_new_contract(self, contract_data: Dict) -> Dict:
        """Create a new contract from grouped data"""
        deal_name = contract_data['deal_name']
        unit = contract_data['unit']
        sub_type = contract_data.get('sub_type', '')
        time_series = contract_data['time_series_data']
        years_covered = contract_data['years_covered']
        contract_type = contract_data['type']
        
        # Get appropriate volume unit
        volume_unit = self.get_volume_unit(contract_type)
        
        # Calculate aggregated values
        total_volume = sum(point['volume'] for point in time_series)
        avg_price = round(sum(point['price'] for point in time_series) / len(time_series), 2) if time_series else 0
        
        # Calculate annual volume - try to get one full calendar year if data exists
        annual_volume = self.calculate_annual_volume(time_series, years_covered, contract_type)
        
        # Determine start and end dates from time series
        timestamps = [datetime.fromisoformat(point['timestamp']) for point in time_series]
        start_date = min(timestamps).strftime('%Y-%m-%d') if timestamps else f"{min(years_covered)}-01-01"
        end_date = max(timestamps).strftime('%Y-%m-%d') if timestamps else f"{max(years_covered)}-12-31"
        
        # Create contract name that includes unit type
        contract_name = f"{deal_name} ({unit})" if unit != 'Energy' else deal_name
        
        new_contract = {
            'name': contract_name,
            'type': contract_type,
            'category': self.map_contract_category(contract_type, deal_name, sub_type),
            'state': contract_data['state'],
            'counterparty': deal_name,  # Use deal name as counterparty
            'startDate': start_date,
            'endDate': end_date,
            'annualVolume': annual_volume,  # Volume for one full CY if available, otherwise total for available data
            'strikePrice': avg_price,
            'unit': volume_unit,  # Use MW for wholesale, MWh for others
            'volumeShape': 'custom',
            'status': 'active',
            'indexation': 'Fixed',
            'referenceDate': start_date,
            'pricingType': 'timeseries',
            'timeSeriesData': time_series,
            'dataSource': 'csv_import',
            'yearsCovered': years_covered,
            'totalVolume': total_volume
        }
        
        return new_contract
    
    def update_contract_with_timeseries(self, contract_id: str, time_series_data: List[Dict]) -> bool:
        """Update existing contract with time series data using PATCH endpoint"""
        try:
            payload = {
                'action': 'updateTimeSeries',
                'contractId': contract_id,
                'timeSeriesData': time_series_data,
                'dataSource': 'csv_import'
            }
            
            response = requests.patch(self.api_base_url, json=payload)
            
            if response.status_code == 200:
                print(f"Successfully updated contract {contract_id} with time series data")
                return True
            else:
                print(f"Error updating contract {contract_id}: {response.status_code} - {response.text}")
                return False
        except Exception as e:
            print(f"Error updating contract {contract_id}: {e}")
            return False
    
    def create_contract_via_api(self, contract_data: Dict) -> str:
        """Create new contract via API and return contract ID"""
        try:
            response = requests.post(self.api_base_url, json=contract_data)
            
            if response.status_code == 201:
                new_contract = response.json()
                contract_id = new_contract.get('_id')
                print(f"Successfully created contract: {contract_data['name']} (ID: {contract_id})")
                return contract_id
            else:
                print(f"Error creating contract {contract_data['name']}: {response.status_code} - {response.text}")
                return None
        except Exception as e:
            print(f"Error creating contract {contract_data['name']}: {e}")
            return None
    
    def process_csv_file(self, filepath: str, dry_run: bool = True, clear_db: bool = False):
        """Main method to process the CSV file and update contracts"""
        print(f"Starting CSV import process (dry_run={dry_run}, clear_db={clear_db})...")
        
        # Clear database if requested
        if clear_db:
            print("\n" + "="*50)
            print("CLEARING DATABASE")
            print("="*50)
            if not dry_run:
                success = self.clear_database()
                if not success:
                    print("Database clearing failed. Aborting import.")
                    return
                print("Database cleared successfully!")
            else:
                print("Would clear all existing contracts from database")
            print()
        
        # Load and clean data
        df = self.load_csv(filepath)
        if df is None:
            return
        
        df_clean = self.clean_and_validate_data(df)
        if len(df_clean) == 0:
            print("No valid data to process")
            return
        
        # Group data by contract
        contracts_data = self.group_data_by_contract(df_clean)
        
        # Fetch existing contracts (will be empty if database was cleared)
        existing_contracts = self.fetch_existing_contracts() if not clear_db or dry_run else []
        
        # Process each contract
        created_count = 0
        updated_count = 0
        error_count = 0
        
        for contract_key, contract_data in contracts_data.items():
            deal_name = contract_data['deal_name']
            unit = contract_data['unit']
            years_covered = contract_data['years_covered']
            time_series = contract_data['time_series_data']
            contract_type = contract_data['type']
            volume_unit = self.get_volume_unit(contract_type)
            
            print(f"\nProcessing: {deal_name} ({unit}) - Type: {contract_type} - Unit: {volume_unit} - Years: {years_covered} - {len(time_series)} data points")
            
            # Check if contract exists (look for deal name with or without unit suffix)
            existing_contract = self.find_matching_contract(deal_name, existing_contracts)
            if not existing_contract and unit != 'Energy':
                # Also try looking for contract name with unit suffix
                contract_name_with_unit = f"{deal_name} ({unit})"
                existing_contract = self.find_matching_contract(contract_name_with_unit, existing_contracts)
            
            if existing_contract:
                # Update existing contract with time series data
                print(f"  → Found existing contract: {existing_contract['name']}")
                
                if not dry_run:
                    success = self.update_contract_with_timeseries(
                        existing_contract['_id'], 
                        time_series
                    )
                    if success:
                        updated_count += 1
                    else:
                        error_count += 1
                else:
                    print(f"  → Would update existing contract with {len(time_series)} time series points")
                    updated_count += 1
            else:
                # Create new contract
                print(f"  → No existing contract found, will create new one")
                new_contract_data = self.create_new_contract(contract_data)
                
                if not dry_run:
                    contract_id = self.create_contract_via_api(new_contract_data)
                    if contract_id:
                        created_count += 1
                    else:
                        error_count += 1
                else:
                    print(f"  → Would create new contract: {new_contract_data['name']}")
                    print(f"     Type: {new_contract_data['type']}, State: {new_contract_data['state']}, Unit: {new_contract_data['unit']}")
                    print(f"     Annual Volume: {new_contract_data['annualVolume']:,.3f} {volume_unit}, Avg Price: ${new_contract_data['strikePrice']:.2f}")
                    print(f"     Total Volume: {new_contract_data['totalVolume']:,.3f} {volume_unit}, Time Series Points: {len(time_series)}, Years: {years_covered}")
                    created_count += 1
        
        # Summary
        print(f"\n{'='*50}")
        print(f"IMPORT SUMMARY ({'DRY RUN' if dry_run else 'LIVE RUN'})")
        print(f"{'='*50}")
        print(f"Contracts created: {created_count}")
        print(f"Contracts updated: {updated_count}")
        print(f"Errors: {error_count}")
        print(f"Total processed: {len(contracts_data)}")
        
        if dry_run:
            print(f"\nThis was a dry run. To execute the import, run with dry_run=False")

# Example usage
if __name__ == "__main__":
    importer = ContractDataImporter("http://localhost:3000/api/contracts")
    
    # First run a dry run to see what would happen (with database clearing)
    print("Running dry run with database clear...")
    importer.process_csv_file("contracts.csv", dry_run=False, clear_db=True)
    
    # Uncomment the line below to execute the actual import with database clearing
    # importer.process_csv_file("contracts.csv", dry_run=False, clear_db=True)
# Out:
# Running dry run with database clear...
# Starting CSV import process (dry_run=False, clear_db=True)...
#
# ==================================================
# CLEARING DATABASE
# ==================================================
# Found 309 contracts to delete...
#   ✓ Deleted: BVC TOU
#   ✓ Deleted: BVC TOU (LGC)
#   ✓ Deleted: CSIRO TOU
#   ✓ Deleted: CSIRO TOU (LGC)
#   ✓ Deleted: Fairfield Non-TOU
#   ✓ Deleted: Fairfield Non-TOU (LGC)
#   ✓ Deleted: Fairfield TOU
#   ✓ Deleted: Fairfield TOU (LGC)
#   ✓ Deleted: SBS TOU
#   ✓ Deleted: SBS TOU (LGC)
#   ✓ Deleted: SSROC Non-TOU
#   ✓ Deleted: SSROC Non-TOU (LGC)
#   ✓ Deleted: SSROC TOU
#   ✓ Deleted: SSROC TOU (LGC)
#   ✓ Deleted: ISPT TOU
#   ✓ Deleted: ISPT TOU (LGC)
#   ✓ Deleted: Adelaide Metro Non-TOU
#   ✓ Deleted: Adelaide Metro Non-TOU (LGC)
#   ✓ Deleted: Adelaide Metro TOU
#   ✓ Deleted: Adelaide Metro TOU (LGC)
#   ✓ Deleted: Bunnings TOU
#   ✓ Deleted: Bunnings TOU (LGC)
#   ✓ Deleted: CBUS TOU
#   ✓ Deleted: CBUS TOU (LGC)
#   ✓ Deleted: Hentley Farm TOU
#   ✓ Deleted: Hentley Farm TOU (LGC)
#   ✓ Deleted: KMART&TARGET TOU
#   ✓ Deleted: KMART&TARGET TOU (LGC)
#   ✓ Deleted: SA Government Non-TOU
#   ✓ Deleted: SA Government Non-TOU (LGC)
#   ✓ Deleted: SACOME TOU
#   ✓ Deleted: SACOME TOU (LGC)
#   ✓ Deleted: Sarstedt TOU
#   ✓ Deleted: Sarstedt TOU (LGC)
#   ✓ Deleted: Sekisui TOU
#   ✓ Deleted: Sekisui TOU (LGC)
#   ✓ Deleted: St John Ambulance Non-TOU
#   ✓ Deleted: St John Ambulance Non-TOU (LGC)
#   ✓ Deleted: Sundrop Farms TOU
#   ✓ Deleted: Sundrop Farms TOU (LGC)
#   ✓ Deleted: Kings The Printer TOU
#   ✓ Deleted: SEEK TOU
#   ✓ Deleted: SEEK TOU (LGC)
#   ✓ Deleted: Villa Maria TOU
#   ✓ Deleted: Villa Maria TOU (LGC)
#   ✓ Deleted: Grass Solar 202203
#   ✓ Deleted: Grass Solar 202203 (LGC)
#   ✓ Deleted: Rocks Wind 202408
#   ✓ Deleted: Rocks Wind 202408 (LGC)
#   ✓ Deleted: Wind 202403
#   ✓ Deleted: Wind 202403 (LGC)
#   ✓ Deleted: Wind 202212
#   ✓ Deleted: SE002274 (LGC)
#   ✓ Deleted: SE002275 (LGC)
#   ✓ Deleted: SE002276 (LGC)
#   ✓ Deleted: SE002277 (LGC)
#   ✓ Deleted: SE002278 (LGC)
#   ✓ Deleted: Templers
#
# Database clearing summary:
#   Deleted: 309
#   Errors: 0
#   Total processed: 309
# Database cleared successfully!
#
# Loaded CSV with 9230 rows and columns: ['buysell', 'Deal_name', 'New_deal_name', 'State', 'type', 'Time', 'Start', 'End', 'Month', 'Year', 'Volume_CY', 'Price_CY', 'Unit', 'Sub_Type', 'Contract_Price', 'Unnamed: 15', 'Cap_Floor_Strike_price', ' Volume ', 'LWP_DWP_%', 'MtM']
# Actual CSV columns (after cleaning): ['buysell', 'Deal_name', 'New_deal_name', 'State', 'type', 'Time', 'Start', 'End', 'Month', 'Year', 'Volume_CY', 'Price_CY', 'Unit', 'Sub_Type', 'Contract_Price', 'Unnamed: 15', 'Cap_Floor_Strike_price', 'Volume', 'LWP_DWP_%', 'MtM']
# Found Volume column: 'Volume'
# Processing Volume column...
# Sample Volume data: [41, 12, 33, 25, 41]
# Cleaned data: 9230 rows remaining
# Contract: BVC TOU (Energy) - Years: [2025]
# Contract: BVC TOU (LGC) - Years: [2025]
# Contract: CSIRO TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: CSIRO TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Fairfield Non-TOU (Energy) - Years: [2025, 2026]
# Contract: Fairfield Non-TOU (LGC) - Years: [2025, 2026]
# Contract: Fairfield TOU (Energy) - Years: [2025, 2026]
# Contract: Fairfield TOU (LGC) - Years: [2025, 2026]
# Contract: Occupier Non-TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041]
# Contract: SBS TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: SBS TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: SSROC Non-TOU (Energy) - Years: [2025, 2026]
# Contract: SSROC Non-TOU (LGC) - Years: [2025, 2026]
# Contract: SSROC TOU (Energy) - Years: [2025, 2026]
# Contract: SSROC TOU (LGC) - Years: [2025, 2026]
# Contract: ISPT Non-TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031]
# Contract: ISPT Non-TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: ISPT TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: ISPT TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Adelaide Metro Non-TOU (Energy) - Years: [2025]
# Contract: Adelaide Metro Non-TOU (LGC) - Years: [2025]
# Contract: Adelaide Metro TOU (Energy) - Years: [2025]
# Contract: Adelaide Metro TOU (LGC) - Years: [2025]
# Contract: Bunnings TOU (Energy) - Years: [2025, 2026, 2027]
# Contract: Bunnings TOU (LGC) - Years: [2025, 2026, 2027]
# Contract: CBUS TOU (Energy) - Years: [2025]
# Contract: CBUS TOU (LGC) - Years: [2025]
# Contract: Hentley Farm TOU (Energy) - Years: [2025]
# Contract: Hentley Farm TOU (LGC) - Years: [2025]
# Contract: KMART&TARGET TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: KMART&TARGET TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: SA Government Non-TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031]
# Contract: SA Government Non-TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: SACOME TOU (Energy) - Years: [2025, 2026, 2027]
# Contract: SACOME TOU (LGC) - Years: [2025, 2026, 2027]
# Contract: Sarstedt TOU (Energy) - Years: [2025]
# Contract: Sarstedt TOU (LGC) - Years: [2025]
# Contract: Sekisui TOU (Energy) - Years: [2025, 2026, 2027]
# Contract: Sekisui TOU (LGC) - Years: [2025, 2026, 2027]
# Contract: St John Ambulance Non-TOU (Energy) - Years: [2025]
# Contract: St John Ambulance Non-TOU (LGC) - Years: [2025]
# Contract: Sundrop Farms TOU (Energy) - Years: [2025]
# Contract: Sundrop Farms TOU (LGC) - Years: [2025]
# Contract: Kings The Printer TOU (Energy) - Years: [2025, 2026, 2027, 2028]
# Contract: SEEK TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract
# Contract: SE002223 (LGC) - Years: [2028]
# Contract: SE002224 (LGC) - Years: [2029]
# Contract: SE002225 (LGC) - Years: [2029]
# Contract: SE002226 (LGC) - Years: [2029]
# Contract: SE002227 (LGC) - Years: [2029]
# Contract: SE002228 (LGC) - Years: [2030]
# Contract: SE002229 (LGC) - Years: [2030]
# Contract: SE002232 (Energy) - Years: [2025]
# Contract: SE002233 (Energy) - Years: [2025]
# Contract: SE002234 (Energy) - Years: [2025]
# Contract: SE002235 (Energy) - Years: [2025]
# Contract: SE002236 (Energy) - Years: [2025]
# Contract: SE002252 (LGC) - Years: [2030]
# Contract: SE002253 (LGC) - Years: [2030]
# Contract: SE002254 (LGC) - Years: [2031]
# Contract: SE002255 (Energy) - Years: [2025]
# Contract: SE002256 (Energy) - Years: [2025]
# Contract: SE002257 (Energy) - Years: [2025]
# Contract: SE002258 (Energy) - Years: [2025]
# Contract: SE002259 (Energy) - Years: [2025]
# Contract: SE002260 (Energy) - Years: [2025]
# Contract: SE002262 (LGC) - Years: [2026]
# Contract: SE002263 (Energy) - Years: [2025]
# Contract: SE002266 (LGC) - Years: [2025]
# Contract: SE002267 (LGC) - Years: [2026]
# Contract: SE002268 (Energy) - Years: [2025]
# Contract: SE002269 (Energy) - Years: [2025]
# Contract: SE002270 (LGC) - Years: [2025]
# Contract: SE002271 (LGC) - Years: [2025]
# Contract: SE002272 (LGC) - Years: [2025]
# Contract: SE002273 (LGC) - Years: [2025]
# Contract: SE002274 (LGC) - Years: [2025]
# Contract: SE002275 (LGC) - Years: [2025]
# Contract: SE002276 (LGC) - Years: [2025]
# Contract: SE002277 (LGC) - Years: [2025]
# Contract: SE002278 (LGC) - Years: [2025]
# Contract: Templers (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045]
# Contract: VIC Retail FY25 B (Energy) - Years: [2025]
# Contract: VIC Retail FY25 Cap B (Energy) - Years: [2025]
# Contract: VIC Retail FY25 Cap S (Energy) - Years: [2025]
# Contract: VIC Retail FY25 S (Energy) - Years: [2025]
# Contract: VIC Solar FY25 B (Energy) - Years: [2025]
# Contract: VIC Solar FY25 Cap B (Energy) - Years: [2025]
# Contract: VIC Solar FY25 Cap S (Energy) - Years: [2025]
# Contract: VIC Solar FY25 Floor B (Energy) - Years: [2025]
# Contract: VIC Solar FY25 Floor S (Energy) - Years: [2025]
# Contract: VIC Solar FY25 S (Energy) - Years: [2025]
# Contract: VIC Wind FY25 B (Energy) - Years: [2025]
# Contract: VIC Wind FY25 Cap B (Energy) - Years: [2025]
# Contract: VIC Wind FY25 Cap S (Energy) - Years: [2025]
# Contract: VIC Wind FY25 Floor B (Energy) - Years: [2025]
# Contract: VIC Wind FY25 Floor S (Energy) - Years: [2025]
# Contract: VIC Wind FY25 S (Energy) - Years: [2025]
# Grouped data into 416 unique contracts
#
# Processing: BVC TOU (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: BVC TOU (ID: 68411ab05821152d37798e2b)
#
# Processing: BVC TOU (LGC) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: BVC TOU (LGC) (ID: 68411ab05821152d37798e2c)
#
# Processing: CSIRO TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 156 data points
#   → No existing contract found, will create new one
# Successfully created contract: CSIRO TOU (ID: 68411ab05821152d37798e2d)
#
# Processing: CSIRO TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 156 data points
#   → No existing contract found, will create new one
# Successfully created contract: CSIRO TOU (LGC) (ID: 68411ab05821152d37798e2e)
#
# Processing: Fairfield Non-TOU (Energy) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: Fairfield Non-TOU (ID: 68411ab05821152d37798e2f)
#
# Processing: Fairfield Non-TOU (LGC) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: Fairfield Non-TOU (LGC) (ID: 68411ab15821152d37798e30)
#
# Processing: Fairfield TOU (Energy) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: Fairfield TOU (ID: 68411ab15821152d37798e31)
#
# Processing: Fairfield TOU (LGC) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: Fairfield TOU (LGC) (ID: 68411ab15821152d37798e32)
#
# Processing: Occupier Non-TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041] - 764 data points
#   → No existing contract found, will create new one
# Error creating contract Occupier Non-TOU: 400 - {"error":"Missing required fields","missingFields":["annualVolume","strikePrice"]}
#
# Processing: SBS TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034] - 224 data points
#   → No existing contract found, will create new one
# Successfully created contract: SBS TOU (ID: 68411ab15821152d37798e33)
#
# Processing: SBS TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034] - 224 data points
#   → No existing contract found, will create new one
# Successfully created contract: SBS TOU (LGC) (ID: 68411ab15821152d37798e34)
#
# Processing: SSROC Non-TOU (Energy) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: SSROC Non-TOU (ID: 68411ab15821152d37798e35)
#
# Processing: SSROC Non-TOU (LGC) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: SSROC Non-TOU (LGC) (ID: 68411ab15821152d37798e36)
#
# Processing: SSROC TOU (Energy) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: SSROC TOU (ID: 68411ab15821152d37798e37)
#
# Processing: SSROC TOU (LGC) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: SSROC TOU (LGC) (ID: 68411ab15821152d37798e38)
#
# Processing: ISPT Non-TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031] - 71 data points
#   → No existing contract found, will create new one
# Error creating contract ISPT Non-TOU: 400 - {"error":"Missing required fields","missingFields":["annualVolume","strikePrice"]}
#
# Processing: ISPT Non-TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 70 data points
#   → No existing contract found, will create new one
# Error creating contract ISPT Non-TOU (LGC): 400 - {"error":"Missing required fields","missingFields":["annualVolume","strikePrice"]}
#
# Processing: ISPT TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 70 data points
#   → No existing contract found, will create new one
# Successfully created contract: ISPT TOU (ID: 68411ab25821152d37798e39)
#
# Processing: ISPT TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 70 data points
#   → No existing contract found, will create new one
# Successfully created contract: ISPT TOU (LGC) (ID: 68411ab25821152d37798e3a)
#
# Processing: Adelaide Metro Non-TOU (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: Adelaide Metro Non-TOU (ID: 68411ab25821152d37798e3b)
#
# Processing: Adelaide Metro Non-TOU (LGC) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: Adelaide Metro Non-TOU (LGC) (ID: 68411ab25821152d37798e3c)
#
# Processing: Adelaide Metro TOU (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: Adelaide Metro TOU (ID: 68411ab25821152d37798e3d)
#
# Processing: Adelaide Metro TOU (LGC) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: Adelaide Metro TOU (LGC) (ID: 68411ab25821152d37798e3e)
#
# Processing: Bunnings TOU (Energy) - Years: [2025, 2026, 2027] - 56 data points
#   → No existing contract found, will create new one
# Successfully created contract: Bunnings TOU (ID: 68411ab25821152d37798e3f)
#
# Processing: Bunnings TOU (LGC) - Years: [2025, 2026, 2027] - 56 data points
#   → No existing contract found, will create new one
# Successfully created contract: Bunnings TOU (LGC) (ID: 68411ab25821152d37798e40)
#
# Processing: CBUS TOU (Energy) - Years: [2025] - 6 data points
#   → No existing contract found, will create new one
# Successfully created contract: CBUS TOU (ID: 68411ab25821152d37798e41)
#
# Processing: CBUS TOU (LGC) - Years: [2025] - 6 data points
#   → No existing contract found, will create new one
# Successfully created contract: CBUS TOU (LGC) (ID: 68411ab35821152d37798e42)
#
# Processing: Hentley Farm TOU (Energy) - Years: [2025] - 10 data points
#   → No existing contract found, will create new one
# Successfully created contract: Hentley Farm TOU (ID: 68411ab35821152d37798e43)
#
# Processing: Hentley Farm TOU (LGC) - Years: [2025] - 10 data points
#   → No existing contract found, will create new one
# Successfully created contract: Hentley Farm TOU (LGC) (ID: 68411ab35821152d37798e44)
#
# Processing: KMART&TARGET TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029] - 116 data points
#   → No existing contract found, will create new one
# Successfully created contract: KMART&TARGET TOU (ID: 68411ab35821152d37798e45)
#
# Processing: KMART&TARGET TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029] - 116 data points
#   → No existing contract found, will create new one
# Successfully created contract: KMART&TARGET TOU (LGC) (ID: 68411ab35821152d37798e46)
#
# Processing: SA Government Non-TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031] - 141 data points
#   → No existing contract found, will create new one
# Successfully created contract: SA Government Non-TOU (ID: 68411ab35821152d37798e47)
#
# Processing: SA Government Non-TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 70 data points
#   → No existing contract found, will create new one
# Successfully created contract: SA Government Non-TOU (LGC) (ID: 68411ab35821152d37798e48)
#
# Processing: SACOME TOU (Energy) - Years: [2025, 2026, 2027] - 28 data points
#   → No existing contract found, will create new one
# Successfully created contract: SACOME TOU (ID: 68411ab35821152d37798e49)
#
# Processing: SACOME TOU (LGC) - Years: [2025, 2026, 2027] - 28 data points
#   → No existing contract found, will create new one
# Successfully created contract: SACOME TOU (LGC) (ID: 68411ab35821152d37798e4a)
#
# Processing: Sarstedt TOU (Energy) - Years: [2025] - 10 data points
#   → No existing contract found, will create new one
# Successfully created contract: Sarstedt TOU (ID: 68411ab35821152d37798e4b)
#
# Processing: Sarstedt TOU (LGC) - Years: [2025] - 10 data points
#   → No existing contract found, will create new one
# Successfully created contract: Sarstedt TOU (LGC) (ID: 68411ab45821152d37798e4c)
#
# Processing: Sekisui TOU (Energy) - Years: [2025, 2026, 2027] - 34 data points
#   → No existing contract found, will create new one
# Successfully created contract: Sekisui TOU (ID: 68411ab45821152d37798e4d)
#
# Processing: Sekisui TOU (LGC) - Years: [2025, 2026, 2027] - 34 data points
#   → No existing contract found, will create new one
# Successfully created contract: Sekisui TOU (LGC) (ID: 68411ab45821152d37798e4e)
#
# Processing: St John Ambulance Non-TOU (Energy) - Years: [2025] - 10 data points
#   → No existing contract found, will create new one
# Successfully created contract: St John Ambulance Non-TOU (ID: 68411ab45821152d37798e4f)
#
# Processing: St John Ambulance Non-TOU (LGC) - Years: [2025] - 10 data points
#   → No existing contract found, will create new one
# Successfully created contract: St John Ambulance Non-TOU (LGC) (ID: 68411ab45821152d37798e50)
#
# Processing: Sundrop Farms TOU (Energy) - Years: [2025] - 10 data points
#   → No existing contract found, will create new one
# Successfully created contract: Sundrop Farms TOU (ID: 68411ab45821152d37798e51)
#
# Processing: Sundrop Farms TOU (LGC) - Years: [2025] - 10 data points
#   → No existing contract found, will create new one
# Successfully created contract: Sundrop Farms TOU (LGC) (ID: 68411ab45821152d37798e52)
#
# Processing: Kings The Printer TOU (Energy) - Years: [2025, 2026, 2027, 2028] - 36 data points
#   → No existing contract found, will create new one
# Successfully created contract: Kings The Printer TOU (ID: 68411ab45821152d37798e53)
#
# Processing: SEEK TOU (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 70 data points
#   → No existing contract found, will create new one
# Successfully created contract: SEEK TOU (ID: 68411ab45821152d37798e54)
#
# Processing: SEEK TOU (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 70 data points
#   → No existing contract found, will create new one
# Successfully created contract: SEEK TOU (LGC) (ID: 68411ab45821152d37798e55)
#
# Processing: Villa Maria TOU (Energy) - Years: [2025, 2026, 2027] - 34 data points
#   → No existing contract found, will create new one
# Successfully created contract: Villa Maria TOU (ID: 68411ab55821152d37798e56)
#
# Processing: Villa Maria TOU (LGC) - Years: [2025, 2026, 2027] - 34 data points
#   → No existing contract found, will create new one
# Successfully created contract: Villa Maria TOU (LGC) (ID: 68411ab55821152d37798e57)
#
# Processing: Blue Grass Solar 202203 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032] - 94 data points
#   → No existing contract found, will create new one
# Successfully created contract: Blue Grass Solar 202203 (ID: 68411ab55821152d37798e58)
#
# Processing: Blue Grass Solar 202203 (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032] - 94 data points
#   → No existing contract found, will create new one
# Successfully created contract: Blue Grass Solar 202203 (LGC) (ID: 68411ab55821152d37798e59)
#
# Processing: Cathedral Rocks Wind 202408 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034] - 112 data points
#   → No existing contract found, will create new one
# Successfully created contract: Cathedral Rocks Wind 202408 (ID: 68411ab55821152d37798e5a)
#
# Processing: Cathedral Rocks Wind 202408 (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034] - 112 data points
#   → No existing contract found, will create new one
# Successfully created contract: Cathedral Rocks Wind 202408 (LGC) (ID: 68411ab55821152d37798e5b)
#
# Processing: Collector Wind 202403 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034] - 109 data points
#   → No existing contract found, will create new one
# Successfully created contract: Collector Wind 202403 (ID: 68411ab55821152d37798e5c)
#
# Processing: Collector Wind 202403 (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034] - 109 data points
#   → No existing contract found, will create new one
# Successfully created contract: Collector Wind 202403 (LGC) (ID: 68411ab55821152d37798e5d)
#
# Processing: Diapur Wind 202212 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032] - 94 data points
#   → No existing contract found, will create new one
# Successfully created contract: Diapur Wind 202212 (ID: 68411ab55821152d37798e5e)
#
# Processing: Diapur Wind 202212 (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032] - 94 data points
#   → No existing contract found, will create new one
# Successfully created contract: Diapur Wind 202212 (LGC) (ID: 68411ab65821152d37798e5f)
#
# Processing: Edenvale Solar 202411 (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: Edenvale Solar 202411 (ID: 68411ab65821152d37798e60)
#
# Processing: Ferguson Wind 202212 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032] - 94 data points
#   → No existing contract found, will create new one
# Successfully created contract: Ferguson Wind 202212 (ID: 68411ab65821152d37798e61)
#
# Processing: Ferguson Wind 202212 (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032] - 94 data points
#   → No existing contract found, will create new one
# Successfully created contract: Ferguson Wind 202212 (LGC) (ID: 68411ab65821152d37798e62)
#
# Processing: Ginan Solar 202406 (Energy) - Years: [2025, 2026, 2027, 2028] - 37 data points
#   → No existing contract found, will create new one
# Successfully created contract: Ginan Solar 202406 (ID: 68411ab65821152d37798e63)
#
# Processing: Ginan Solar 202406 (LGC) - Years: [2025, 2026, 2027, 2028] - 37 data points
#   → No existing contract found, will create new one
# Successfully created contract: Ginan Solar 202406 (LGC) (ID: 68411ab65821152d37798e64)
#
# Processing: Gunnedah Solar 202407 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 61 data points
#   → No existing contract found, will create new one
# Successfully created contract: Gunnedah Solar 202407 (ID: 68411ab65821152d37798e65)
#
# Processing: Hay Solar 202409 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 60 data points
#   → No existing contract found, will create new one
# Successfully created contract: Hay Solar 202409 (ID: 68411ab65821152d37798e66)
#
# Processing: Hillston 1 Solar 202409 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 61 data points
#   → No existing contract found, will create new one
# Successfully created contract: Hillston 1 Solar 202409 (ID: 68411ab65821152d37798e67)
#
# Processing: Hillston 2 Solar 202409 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 63 data points
#   → No existing contract found, will create new one
# Successfully created contract: Hillston 2 Solar 202409 (ID: 68411ab75821152d37798e68)
#
# Processing: Kerang Solar 202408 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035] - 120 data points
#   → No existing contract found, will create new one
# Successfully created contract: Kerang Solar 202408 (ID: 68411ab75821152d37798e69)
#
# Processing: Kerang Solar 202408 (LGC) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035] - 120 data points
#   → No existing contract found, will create new one
# Successfully created contract: Kerang Solar 202408 (LGC) (ID: 68411ab75821152d37798e6a)
#
# Processing: Kootingal Solar 202407 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030] - 59 data points
#   → No existing contract found, will create new one
# Successfully created contract: Kootingal Solar 202407 (ID: 68411ab75821152d37798e6b)
#
# Processing: Moree Solar 202202 (Energy) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: Moree Solar 202202 (ID: 68411ab75821152d37798e6c)
#
# Processing: Moree Solar 202202 (LGC) - Years: [2025, 2026] - 22 data points
#   → No existing contract found, will create new one
# Successfully created contract: Moree Solar 202202 (LGC) (ID: 68411ab75821152d37798e6d)
#
# Processing: Mortons Lane Wind 202212 (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032] - 94 data points
#   → No existing contract found, will create new one
# Successfully created contract: Mortons Lane Wind 202212 (ID: 68411ab75821152d37798e6e)
#
# ...
#
# Processing: SE002183 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002183 (ID: 68411ace5821152d37798f40)
#
# Processing: SE002184 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002184 (ID: 68411ace5821152d37798f41)
#
# Processing: SE002185 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002185 (ID: 68411acf5821152d37798f42)
#
# Processing: SE002186 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002186 (ID: 68411acf5821152d37798f43)
#
# Processing: SE002191 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002191 (ID: 68411acf5821152d37798f44)
#
# Processing: SE002193 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002193 (ID: 68411acf5821152d37798f45)
#
# Processing: SE002194 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002194 (ID: 68411acf5821152d37798f46)
#
# Processing: SE002195 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002195 (ID: 68411acf5821152d37798f47)
#
# Processing: SE002196 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002196 (ID: 68411acf5821152d37798f48)
#
# Processing: SE002197 (Energy) - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002197 (ID: 68411acf5821152d37798f49)
#
# Processing: SE002198 (Energy) - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002198 (ID: 68411acf5821152d37798f4a)
#
# Processing: SE002199 (Energy) - Years: [2026] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002199 (ID: 68411acf5821152d37798f4b)
#
# Processing: SE002200 (Energy) - Years: [2026] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002200 (ID: 68411ad05821152d37798f4c)
#
# Processing: SE002201 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002201 (ID: 68411ad05821152d37798f4d)
#
# Processing: SE002202 (Energy) - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002202 (ID: 68411ad05821152d37798f4e)
#
# Processing: SE002203 (Energy) - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002203 (ID: 68411ad05821152d37798f4f)
#
# Processing: SE002211 (Energy) - Years: [2026] - 12 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE
Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002263 (ID: 68411ad45821152d37798f72)
#
# Processing: SE002266 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002266 (LGC) (ID: 68411ad45821152d37798f73)
#
# Processing: SE002267 (LGC) - Years: [2026] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002267 (LGC) (ID: 68411ad45821152d37798f74)
#
# Processing: SE002268 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002268 (ID: 68411ad45821152d37798f75)
#
# Processing: SE002269 (Energy) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002269 (ID: 68411ad45821152d37798f76)
#
# Processing: SE002270 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002270 (LGC) (ID: 68411ad45821152d37798f77)
#
# Processing: SE002271 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002271 (LGC) (ID: 68411ad45821152d37798f78)
#
# Processing: SE002272 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002272 (LGC) (ID: 68411ad45821152d37798f79)
#
# Processing: SE002273 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002273 (LGC) (ID: 68411ad45821152d37798f7a)
#
# Processing: SE002274 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002274 (LGC) (ID: 68411ad55821152d37798f7b)
#
# Processing: SE002275 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002275 (LGC) (ID: 68411ad55821152d37798f7c)
#
# Processing: SE002276 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002276 (LGC) (ID: 68411ad55821152d37798f7d)
#
# Processing: SE002277 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002277 (LGC) (ID: 68411ad55821152d37798f7e)
#
# Processing: SE002278 (LGC) - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002278 (LGC) (ID: 68411ad55821152d37798f7f)
#
# Processing: Templers (Energy) - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045] - 242 data points
#   → No existing contract found, will create new one
# Successfully created contract: Templers (ID: 68411ad55821152d37798f80)
#
# Processing: VIC Retail FY25 B (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Retail FY25 B (ID: 68411ad55821152d37798f81)
#
# Processing: VIC Retail FY25 Cap B (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Retail FY25 Cap B (ID: 68411ad55821152d37798f82)
#
# Processing: VIC Retail FY25 Cap S (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Retail FY25 Cap S (ID: 68411ad55821152d37798f83)
#
# Processing: VIC Retail FY25 S (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Retail FY25 S (ID: 68411ad55821152d37798f84)
#
# Processing: VIC Solar FY25 B (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 B (ID: 68411ad65821152d37798f85)
#
# Processing: VIC Solar FY25 Cap B (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 Cap B (ID: 68411ad65821152d37798f86)
#
# Processing: VIC Solar FY25 Cap S (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 Cap S (ID: 68411ad65821152d37798f87)
#
# Processing: VIC Solar FY25 Floor B (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Error creating contract VIC Solar FY25 Floor B: 400 - {"error":"Missing required fields","missingFields":["strikePrice"]}
#
# Processing: VIC Solar FY25 Floor S (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Error creating contract VIC Solar FY25 Floor S: 400 - {"error":"Missing required fields","missingFields":["strikePrice"]}
#
# Processing: VIC Solar FY25 S (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 S (ID: 68411ad65821152d37798f88)
#
# Processing: VIC Wind FY25 B (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 B (ID: 68411ad65821152d37798f89)
#
# Processing: VIC Wind FY25 Cap B (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 Cap B (ID: 68411ad65821152d37798f8a)
#
# Processing: VIC Wind FY25 Cap S (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 Cap S (ID: 68411ad65821152d37798f8b)
#
# Processing: VIC Wind FY25 Floor B (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Error creating contract VIC Wind FY25 Floor B: 400 - {"error":"Missing required fields","missingFields":["strikePrice"]}
#
# Processing: VIC Wind FY25 Floor S (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Error creating contract VIC Wind FY25 Floor S: 400 - {"error":"Missing required fields","missingFields":["strikePrice"]}
#
# Processing: VIC Wind FY25 S (Energy) - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 S (ID: 68411ad75821152d37798f8c)
#
# ==================================================
# IMPORT SUMMARY (LIVE RUN)
# ==================================================
# Contracts created: 354
# Contracts updated: 0
# Errors: 62
# Total processed: 416
