# %%
import pandas as pd
import requests
import json
from datetime import datetime, timedelta
from typing import Dict, List, Any
import re
import calendar

class ContractDataImporter:
    def __init__(self, api_base_url: str = "http://localhost:3000/api/contracts"):
        self.api_base_url = api_base_url
        self.contracts_cache = {}
        
    def load_csv(self, filepath: str) -> pd.DataFrame:
        """Load and parse the CSV file"""
        try:
            df = pd.read_csv(filepath)
            print(f"Loaded CSV with {len(df)} rows and columns: {list(df.columns)}")
            return df
        except Exception as e:
            print(f"Error loading CSV: {e}")
            return None
    
    def clean_and_validate_data(self, df: pd.DataFrame) -> pd.DataFrame:
        """Clean and validate the CSV data"""
        # Clean column names by stripping whitespace
        df.columns = df.columns.str.strip()
        
        # Print actual columns for debugging
        print(f"Actual CSV columns (after cleaning): {list(df.columns)}")
        
        # Map columns to find the right ones based on new structure
        column_mapping = {}
        
        # Required columns mapping for new CSV structure
        required_mappings = {
            'Trade': 'Trade',  # New column for buy/sell
            'New_deal_name': 'New_deal_name',
            'State': 'State', 
            'type': 'type',
            'Year': 'Year',
            'Month': 'Month',
            'Volume': 'Volume',
            'AvestrikePrice': 'AvestrikePrice',  # Changed from Price_CY
            'unit': 'unit',
            'ContractType': 'ContractType',  # New column
            'Sub_Type': 'Sub_Type',
            'StartDate': 'StartDate',  # New column
            'EndDate': 'EndDate'       # New column
        }
        
        # Find matching columns
        for standard_name, csv_name in required_mappings.items():
            matching_cols = [col for col in df.columns if csv_name.lower() == col.lower()]
            if matching_cols:
                column_mapping[standard_name] = matching_cols[0]
            else:
                print(f"Warning: Could not find column matching '{csv_name}'")
        
        # Check if we found all critical columns
        critical_columns = ['New_deal_name', 'State', 'type', 'Year', 'Month', 'Volume', 'AvestrikePrice']
        missing_critical = [col for col in critical_columns if col not in column_mapping]
        
        if missing_critical:
            print(f"Missing critical columns: {missing_critical}")
            return pd.DataFrame()  # Return empty dataframe if critical columns missing
        
        # Clean data
        df_clean = df.copy()
        
        # Rename columns to standard names for easier processing
        df_clean = df_clean.rename(columns={v: k for k, v in column_mapping.items()})
        
        # Convert Volume to numeric, handling commas and dashes
        if 'Volume' in df_clean.columns:
            print(f"Processing Volume column...")
            df_clean['Volume'] = df_clean['Volume'].astype(str).str.replace(',', '').str.replace('-', '0').str.strip()
            df_clean['Volume'] = pd.to_numeric(df_clean['Volume'], errors='coerce').fillna(0)
            print(f"Sample Volume data: {df_clean['Volume'].head().tolist()}")
        
        # Convert AvestrikePrice to numeric
        if 'AvestrikePrice' in df_clean.columns:
            df_clean['AvestrikePrice'] = df_clean['AvestrikePrice'].astype(str).str.replace(',', '').str.strip()
            df_clean['AvestrikePrice'] = pd.to_numeric(df_clean['AvestrikePrice'], errors='coerce').fillna(0)
        
        # Remove rows with missing deal names
        df_clean = df_clean.dropna(subset=['New_deal_name'])
        
        print(f"Cleaned data: {len(df_clean)} rows remaining")
        return df_clean
    
    def parse_date_from_row(self, row) -> str:
        """Parse date from Year and Month columns"""
        try:
            year = int(row['Year'])
            month = int(row['Month'])
            # Create first day of the month as timestamp
            date = datetime(year, month, 1)
            return date.isoformat()
        except:
            return datetime.now().isoformat()
    
    def get_hours_in_period(self, year: int, month: int) -> int:
        """Get the number of hours in a given month"""
        days_in_month = calendar.monthrange(year, month)[1]
        return days_in_month * 24
    
    def convert_volume_for_contract_type(self, volume_mwh: float, contract_type: str, year: int, month: int) -> float:
        """Convert MWh to appropriate unit based on contract type"""
        if contract_type == 'wholesale':
            # Convert MWh to MW by dividing by hours in the period
            hours_in_period = self.get_hours_in_period(year, month)
            volume_mw = volume_mwh / hours_in_period
            return round(volume_mw, 3)  # Round to 3 decimal places for MW
        else:
            # Retail and offtake contracts keep MWh
            return round(volume_mwh, 0)  # Round to whole MWh
    
    def get_volume_unit(self, contract_type: str) -> str:
        """Get the appropriate volume unit based on contract type"""
        if contract_type == 'wholesale':
            return 'MW'
        else:
            return 'MWh'
    
    def map_contract_type(self, csv_type: str) -> str:
        """Map CSV type to contract type"""
        type_mapping = {
            'Retail': 'retail',
            'Wholesale': 'wholesale', 
            'Offtake': 'offtake'
        }
        return type_mapping.get(csv_type, 'retail')
    
    def map_trade_direction(self, trade_value: str) -> str:
        """Map Trade column value to standard buy/sell format"""
        if not trade_value or pd.isna(trade_value):
            return 'sell'  # Default to sell
        
        trade_lower = str(trade_value).lower().strip()
        if 'buy' in trade_lower or 'purchase' in trade_lower:
            return 'buy'
        else:
            return 'sell'
    
    def map_contract_category(self, contract_type: str, deal_name: str, sub_type: str = None) -> str:
        """Determine contract category based on type, deal name, and sub_type"""
        if contract_type == 'retail':
            if 'Government' in deal_name or 'Gov' in deal_name:
                return 'Government Customer'
            elif 'Industrial' in deal_name or 'Mining' in deal_name:
                return 'Industrial Customer'
            else:
                return 'Retail Customer'
        elif contract_type == 'wholesale':
            # Use Sub_Type for wholesale contracts
            if sub_type and sub_type.strip():
                return sub_type.strip()
            else:
                return 'Swap'  # Default fallback
        else:  # offtake
            if 'Solar' in deal_name:
                return 'Solar Farm'
            elif 'Wind' in deal_name:
                return 'Wind Farm'
            else:
                return 'Solar Farm'
    
    def group_data_by_contract(self, df: pd.DataFrame) -> Dict[str, List[Dict]]:
        """Group data by unique deal name (aggregating all years) and contract type"""
        contracts_data = {}
        
        for _, row in df.iterrows():
            deal_name = row['New_deal_name']
            year = row['Year']
            contract_type_from_csv = row.get('ContractType', 'Energy')  # Energy or LGC
            sub_type = row.get('Sub_Type', '')  # Get Sub_Type for wholesale contracts
            contract_type = self.map_contract_type(row['type'])
            trade_direction = self.map_trade_direction(row.get('Trade', 'Sell'))
            
            # Create unique key for contract (deal name + contract type from CSV)
            contract_key = f"{deal_name}_{contract_type_from_csv}"
            
            if contract_key not in contracts_data:
                contracts_data[contract_key] = {
                    'deal_name': deal_name,
                    'contract_type_csv': contract_type_from_csv,  # Energy or LGC
                    'sub_type': sub_type,
                    'state': row['State'],
                    'type': contract_type,  # retail, wholesale, offtake
                    'trade_direction': trade_direction,  # buy or sell
                    'time_series_data': [],
                    'years_covered': set(),
                    'contract_info': {
                        'start_date': row.get('StartDate', ''),
                        'end_date': row.get('EndDate', ''),
                        'unit': row.get('unit', 'MWh')
                    }
                }
            
            # Add year to covered years
            contracts_data[contract_key]['years_covered'].add(year)
            
            # Convert volume based on contract type
            original_volume_mwh = float(row['Volume'])
            converted_volume = self.convert_volume_for_contract_type(
                original_volume_mwh, contract_type, year, row['Month']
            )
            
            # Add time series point
            timestamp = self.parse_date_from_row(row)
            period = f"{year}-{str(row['Month']).zfill(2)}"
            
            time_point = {
                'timestamp': timestamp,
                'volume': converted_volume,
                'price': round(float(row['AvestrikePrice']), 2),  # Round to 2 decimal places
                'period': period,
                'periodType': 'monthly'
            }
            
            contracts_data[contract_key]['time_series_data'].append(time_point)
        
        # Convert years_covered set to sorted list for better display
        for contract_key in contracts_data:
            years_list = sorted(list(contracts_data[contract_key]['years_covered']))
            contracts_data[contract_key]['years_covered'] = years_list
            volume_unit = self.get_volume_unit(contracts_data[contract_key]['type'])
            trade_dir = contracts_data[contract_key]['trade_direction']
            print(f"Contract: {contracts_data[contract_key]['deal_name']} ({contracts_data[contract_key]['contract_type_csv']}) - Type: {contracts_data[contract_key]['type']} - Unit: {volume_unit} - Trade: {trade_dir} - Years: {years_list}")
        
        print(f"Grouped data into {len(contracts_data)} unique contracts")
        return contracts_data
    
    def calculate_annual_volume(self, time_series: List[Dict], years_covered: List[int], contract_type: str) -> float:
        """Calculate volume for one full calendar year if data exists, otherwise return total"""
        if not time_series:
            return 0
        
        # Group time series by year
        yearly_volumes = {}
        for point in time_series:
            timestamp = datetime.fromisoformat(point['timestamp'])
            year = timestamp.year
            
            if year not in yearly_volumes:
                yearly_volumes[year] = {'volume': 0, 'months': set()}
            
            yearly_volumes[year]['volume'] += point['volume']
            yearly_volumes[year]['months'].add(timestamp.month)
        
        # Check if we have any complete year (12 months of data)
        complete_years = []
        for year, data in yearly_volumes.items():
            if len(data['months']) == 12:  # Full calendar year
                complete_years.append((year, data['volume']))
        
        if complete_years:
            # Return volume from the most recent complete year
            complete_years.sort(key=lambda x: x[0], reverse=True)  # Sort by year, newest first
            volume = complete_years[0][1]
        else:
            # No complete year found, return total volume for all available data
            volume = sum(point['volume'] for point in time_series)
        
        # Round appropriately based on contract type
        if contract_type == 'wholesale':
            return round(volume, 3)  # MW to 3 decimal places
        else:
            return round(volume, 0)  # MWh to whole numbers
    
    def clear_database(self) -> bool:
        """Clear all contracts from the database"""
        try:
            # First fetch all contracts to get their IDs
            response = requests.get(self.api_base_url)
            if response.status_code != 200:
                print(f"Error fetching contracts for deletion: {response.status_code}")
                return False
            
            contracts = response.json()
            print(f"Found {len(contracts)} contracts to delete...")
            
            deleted_count = 0
            error_count = 0
            
            for contract in contracts:
                contract_id = contract.get('_id') or contract.get('id')
                if contract_id:
                    try:
                        delete_response = requests.delete(f"{self.api_base_url}?id={contract_id}")
                        if delete_response.status_code == 200:
                            deleted_count += 1
                            print(f"  ✓ Deleted: {contract.get('name', 'Unknown')}")
                        else:
                            error_count += 1
                            print(f"  ✗ Error deleting {contract.get('name', 'Unknown')}: {delete_response.status_code}")
                    except Exception as e:
                        error_count += 1
                        print(f"  ✗ Error deleting {contract.get('name', 'Unknown')}: {e}")
                else:
                    error_count += 1
                    print(f"  ✗ No ID found for contract: {contract.get('name', 'Unknown')}")
            
            print(f"\nDatabase clearing summary:")
            print(f"  Deleted: {deleted_count}")
            print(f"  Errors: {error_count}")
            print(f"  Total processed: {len(contracts)}")
            
            return error_count == 0
            
        except Exception as e:
            print(f"Error clearing database: {e}")
            return False
    
    def fetch_existing_contracts(self) -> List[Dict]:
        """Fetch existing contracts from API"""
        try:
            response = requests.get(self.api_base_url)
            if response.status_code == 200:
                contracts = response.json()
                print(f"Fetched {len(contracts)} existing contracts")
                return contracts
            else:
                print(f"Error fetching contracts: {response.status_code}")
                return []
        except Exception as e:
            print(f"Error fetching contracts: {e}")
            return []
    
    def find_matching_contract(self, deal_name: str, existing_contracts: List[Dict]) -> Dict:
        """Find existing contract that matches the deal name"""
        for contract in existing_contracts:
            if contract['name'].lower() == deal_name.lower():
                return contract
        return None
    
    def calculate_annual_strike_prices(self, time_series: List[Dict]) -> Dict[int, float]:
        """Calculate volume-weighted average strike price for each calendar year"""
        if not time_series:
            return {}
        
        # Group by year and calculate volume-weighted averages
        yearly_data = {}
        for point in time_series:
            timestamp = datetime.fromisoformat(point['timestamp'])
            year = timestamp.year
            
            if year not in yearly_data:
                yearly_data[year] = {'total_value': 0, 'total_volume': 0}
            
            # Volume-weighted calculation
            value = point['price'] * point['volume']
            yearly_data[year]['total_value'] += value
            yearly_data[year]['total_volume'] += point['volume']
        
        # Calculate weighted averages
        annual_prices = {}
        for year, data in yearly_data.items():
            if data['total_volume'] > 0:
                annual_prices[year] = round(data['total_value'] / data['total_volume'], 2)
            else:
                annual_prices[year] = 0
        
        return annual_prices

    def get_representative_strike_price(self, time_series: List[Dict], years_covered: List[int]) -> float:
        """Get a representative strike price for the contract"""
        annual_prices = self.calculate_annual_strike_prices(time_series)
        
        if not annual_prices:
            return 0
        
        # If we have multiple years, use the most recent complete year's price
        # Otherwise use the average across all available data
        if len(annual_prices) == 1:
            return list(annual_prices.values())[0]
        else:
            # Return the most recent year's price
            most_recent_year = max(annual_prices.keys())
            return annual_prices[most_recent_year]

    def create_new_contract(self, contract_data: Dict) -> Dict:
        """Create a new contract from grouped data"""
        deal_name = contract_data['deal_name']
        contract_type_csv = contract_data['contract_type_csv']
        sub_type = contract_data.get('sub_type', '')
        time_series = contract_data['time_series_data']
        years_covered = contract_data['years_covered']
        contract_type = contract_data['type']
        trade_direction = contract_data['trade_direction']
        contract_info = contract_data['contract_info']
        
        # Get appropriate volume unit
        volume_unit = self.get_volume_unit(contract_type)
        
        # Process time series data similar to volume editor
        # Sort time series by timestamp to ensure proper ordering
        time_series_sorted = sorted(time_series, key=lambda x: x['timestamp'])
        
        # Calculate aggregated values
        total_volume = sum(point['volume'] for point in time_series_sorted)
        
        # Calculate representative strike price and annual prices
        strike_price = self.get_representative_strike_price(time_series_sorted, years_covered)
        annual_strike_prices = self.calculate_annual_strike_prices(time_series_sorted)
        
        # Calculate annual volume - try to get one full calendar year if data exists
        annual_volume = self.calculate_annual_volume(time_series_sorted, years_covered, contract_type)
        
        # Use EndDate from CSV if available, otherwise calculate from time series
        if contract_info.get('end_date') and contract_info['end_date'].strip():
            end_date = contract_info['end_date'].strip()
            # Convert to YYYY-MM-DD format if needed
            try:
                # Try parsing different date formats and convert to YYYY-MM-DD
                if '/' in end_date:
                    # Handle DD/MM/YYYY or MM/DD/YYYY format
                    date_obj = datetime.strptime(end_date, '%d/%m/%Y')
                    end_date = date_obj.strftime('%Y-%m-%d')
                elif len(end_date) == 10 and end_date[4] == '-':
                    # Already in YYYY-MM-DD format
                    pass
                else:
                    # Try other formats if needed
                    date_obj = datetime.strptime(end_date, '%Y-%m-%d')
                    end_date = date_obj.strftime('%Y-%m-%d')
            except:
                # If parsing fails, fall back to time series calculation
                timestamps = [datetime.fromisoformat(point['timestamp']) for point in time_series_sorted]
                end_date = max(timestamps).strftime('%Y-%m-%d') if timestamps else f"{max(years_covered)}-12-31"
        else:
            # Fall back to calculating from time series
            timestamps = [datetime.fromisoformat(point['timestamp']) for point in time_series_sorted]
            end_date = max(timestamps).strftime('%Y-%m-%d') if timestamps else f"{max(years_covered)}-12-31"
        
        # Use StartDate from CSV if available, otherwise calculate from time series
        if contract_info.get('start_date') and contract_info['start_date'].strip():
            start_date = contract_info['start_date'].strip()
            # Convert to YYYY-MM-DD format if needed
            try:
                if '/' in start_date:
                    # Handle DD/MM/YYYY or MM/DD/YYYY format
                    date_obj = datetime.strptime(start_date, '%d/%m/%Y')
                    start_date = date_obj.strftime('%Y-%m-%d')
                elif len(start_date) == 10 and start_date[4] == '-':
                    # Already in YYYY-MM-DD format
                    pass
                else:
                    # Try other formats if needed
                    date_obj = datetime.strptime(start_date, '%Y-%m-%d')
                    start_date = date_obj.strftime('%Y-%m-%d')
            except:
                # If parsing fails, fall back to time series calculation
                timestamps = [datetime.fromisoformat(point['timestamp']) for point in time_series_sorted]
                start_date = min(timestamps).strftime('%Y-%m-%d') if timestamps else f"{min(years_covered)}-01-01"
        else:
            # Fall back to calculating from time series
            timestamps = [datetime.fromisoformat(point['timestamp']) for point in time_series_sorted]
            start_date = min(timestamps).strftime('%Y-%m-%d') if timestamps else f"{min(years_covered)}-01-01"
        
        # Create contract name that includes contract type if not Energy
        contract_name = f"{deal_name} ({contract_type_csv})" if contract_type_csv != 'Energy' else deal_name
        
        new_contract = {
            'name': contract_name,
            'type': contract_type,
            'category': self.map_contract_category(contract_type, deal_name, sub_type),
            'state': contract_data['state'],
            'counterparty': deal_name,  # Use deal name as counterparty
            'startDate': start_date,
            'endDate': end_date,
            'annualVolume': annual_volume,  # Volume for one full CY if available, otherwise total for available data
            'strikePrice': strike_price,  # Representative strike price
            'unit': volume_unit,  # Use MW for wholesale, MWh for others
            'volumeShape': 'custom',  # Always custom since we have time series data
            'status': 'active',
            'indexation': 'Fixed',
            'referenceDate': start_date,
            'pricingType': 'timeseries',
            'timeSeriesData': time_series_sorted,  # Store all monthly data points
            'dataSource': 'csv_import',
            'yearsCovered': years_covered,
            'totalVolume': total_volume,
            'contractType': contract_type_csv,  # Energy or LGC
            'tradeDirection': trade_direction,  # buy or sell
            'annualStrikePrices': annual_strike_prices  # One strike price per calendar year
        }
        
        return new_contract
    
    def update_contract_with_timeseries(self, contract_id: str, contract_data: Dict) -> bool:
        """Update existing contract with time series data and pricing using PATCH endpoint"""
        try:
            # Calculate annual strike prices for the update
            time_series = contract_data['time_series_data']
            annual_strike_prices = self.calculate_annual_strike_prices(time_series)
            representative_price = self.get_representative_strike_price(time_series, contract_data['years_covered'])
            
            payload = {
                'action': 'updateTimeSeries',
                'contractId': contract_id,
                'timeSeriesData': time_series,
                'dataSource': 'csv_import',
                'totalVolume': contract_data['total_volume'],
                'yearsCovered': contract_data['years_covered'],
                'strikePrice': representative_price,  # Update main strike price
                'annualStrikePrices': annual_strike_prices,  # Add annual prices
                'tradeDirection': contract_data['trade_direction']  # Update trade direction
            }
            
            response = requests.patch(self.api_base_url, json=payload)
            
            if response.status_code == 200:
                print(f"Successfully updated contract {contract_id} with time series data and pricing")
                return True
            else:
                print(f"Error updating contract {contract_id}: {response.status_code} - {response.text}")
                return False
        except Exception as e:
            print(f"Error updating contract {contract_id}: {e}")
            return False
    
    def create_contract_via_api(self, contract_data: Dict) -> str:
        """Create new contract via API and return contract ID"""
        try:
            response = requests.post(self.api_base_url, json=contract_data)
            
            if response.status_code == 201:
                new_contract = response.json()
                contract_id = new_contract.get('_id')
                print(f"Successfully created contract: {contract_data['name']} (ID: {contract_id})")
                return contract_id
            else:
                print(f"Error creating contract {contract_data['name']}: {response.status_code} - {response.text}")
                return None
        except Exception as e:
            print(f"Error creating contract {contract_data['name']}: {e}")
            return None
    
    def process_csv_file(self, filepath: str, dry_run: bool = True, clear_db: bool = False):
        """Main method to process the CSV file and update contracts"""
        print(f"Starting CSV import process (dry_run={dry_run}, clear_db={clear_db})...")
        
        # Clear database if requested
        if clear_db:
            print("\n" + "="*50)
            print("CLEARING DATABASE")
            print("="*50)
            if not dry_run:
                success = self.clear_database()
                if not success:
                    print("Database clearing failed. Aborting import.")
                    return
                print("Database cleared successfully!")
            else:
                print("Would clear all existing contracts from database")
            print()
        
        # Load and clean data
        df = self.load_csv(filepath)
        if df is None:
            return
        
        df_clean = self.clean_and_validate_data(df)
        if len(df_clean) == 0:
            print("No valid data to process")
            return
        
        # Group data by contract
        contracts_data = self.group_data_by_contract(df_clean)
        
        # Fetch existing contracts (will be empty if database was cleared)
        existing_contracts = self.fetch_existing_contracts() if not clear_db or dry_run else []
        
        # Process each contract
        created_count = 0
        updated_count = 0
        error_count = 0
        
        for contract_key, contract_data in contracts_data.items():
            deal_name = contract_data['deal_name']
            contract_type_csv = contract_data['contract_type_csv']
            years_covered = contract_data['years_covered']
            time_series = contract_data['time_series_data']
            contract_type = contract_data['type']
            trade_direction = contract_data['trade_direction']
            volume_unit = self.get_volume_unit(contract_type)
            
            print(f"\nProcessing: {deal_name} ({contract_type_csv}) - Type: {contract_type} - Unit: {volume_unit} - Trade: {trade_direction} - Years: {years_covered} - {len(time_series)} data points")
            
            # Check if contract exists (look for deal name with or without contract type suffix)
            existing_contract = self.find_matching_contract(deal_name, existing_contracts)
            if not existing_contract and contract_type_csv != 'Energy':
                # Also try looking for contract name with contract type suffix
                contract_name_with_type = f"{deal_name} ({contract_type_csv})"
                existing_contract = self.find_matching_contract(contract_name_with_type, existing_contracts)
            
            if existing_contract:
                # Update existing contract with time series data
                print(f"  → Found existing contract: {existing_contract['name']}")
                
                # Prepare contract data for update
                update_data = {
                    'time_series_data': time_series,
                    'total_volume': sum(point['volume'] for point in time_series),
                    'years_covered': years_covered,
                    'trade_direction': trade_direction
                }
                
                if not dry_run:
                    success = self.update_contract_with_timeseries(
                        existing_contract['_id'], 
                        update_data
                    )
                    if success:
                        updated_count += 1
                    else:
                        error_count += 1
                else:
                    print(f"  → Would update existing contract with {len(time_series)} time series points")
                    annual_prices = self.calculate_annual_strike_prices(time_series)
                    print(f"     Annual Strike Prices: {annual_prices}")
                    print(f"     Trade Direction: {trade_direction}")
                    updated_count += 1
            else:
                # Create new contract
                print(f"  → No existing contract found, will create new one")
                new_contract_data = self.create_new_contract(contract_data)
                
                if not dry_run:
                    contract_id = self.create_contract_via_api(new_contract_data)
                    if contract_id:
                        created_count += 1
                    else:
                        error_count += 1
                else:
                    print(f"  → Would create new contract: {new_contract_data['name']}")
                    print(f"     Type: {new_contract_data['type']}, State: {new_contract_data['state']}, Unit: {new_contract_data['unit']}")
                    print(f"     Trade Direction: {new_contract_data['tradeDirection']}, Contract Type: {new_contract_data['contractType']}")
                    print(f"     Annual Volume: {new_contract_data['annualVolume']:,.3f} {volume_unit}, Strike Price: ${new_contract_data['strikePrice']:.2f}")
                    print(f"     Total Volume: {new_contract_data['totalVolume']:,.3f} {volume_unit}, Time Series Points: {len(time_series)}, Years: {years_covered}")
                    print(f"     Annual Strike Prices: {new_contract_data['annualStrikePrices']}")
                    print(f"     Start Date: {new_contract_data['startDate']}, End Date: {new_contract_data['endDate']}")
                    created_count += 1
        
        # Summary
        print(f"\n{'='*50}")
        print(f"IMPORT SUMMARY ({'DRY RUN' if dry_run else 'LIVE RUN'})")
        print(f"{'='*50}")
        print(f"Contracts created: {created_count}")
        print(f"Contracts updated: {updated_count}")
        print(f"Errors: {error_count}")
        print(f"Total processed: {len(contracts_data)}")
        
        if dry_run:
            print(f"\nThis was a dry run. To execute the import, run with dry_run=False")

# Example usage
if __name__ == "__main__":
    importer = ContractDataImporter("http://localhost:3000/api/contracts")
    
    # First run a dry run to see what would happen
    print("Running dry run...")
    importer.process_csv_file("contracts.csv", dry_run=False, clear_db=True)
    
    # Uncomment the line below to execute the actual import
    # importer.process_csv_file("contracts.csv", dry_run=False, clear_db=False)
# Out:
# Running dry run...
# Starting CSV import process (dry_run=False, clear_db=True)...
#
# ==================================================
# CLEARING DATABASE
# ==================================================
# Found 412 contracts to delete...
#   ✓ Deleted: BVC TOU
#   ✓ Deleted: BVC TOU (Green)
#   ✓ Deleted: CSIRO TOU
#   ✓ Deleted: CSIRO TOU (Green)
#   ✓ Deleted: Fairfield Non-TOU
#   ✓ Deleted: Fairfield Non-TOU (Green)
#   ✓ Deleted: Fairfield TOU
#   ✓ Deleted: Fairfield TOU (Green)
#   ✓ Deleted: Occupier Non-TOU
#   ✓ Deleted: SBS TOU
#   ✓ Deleted: SBS TOU (Green)
#   ✓ Deleted: SSROC Non-TOU
#   ✓ Deleted: SSROC Non-TOU (Green)
#   ✓ Deleted: SSROC TOU
#   ✓ Deleted: SSROC TOU (Green)
#   ✓ Deleted: ISPT Non-TOU
#   ✓ Deleted: ISPT Non-TOU (Green)
#   ✓ Deleted: ISPT TOU
#   ✓ Deleted: ISPT TOU (Green)
#   ✓ Deleted: Adelaide Metro Non-TOU
#   ✓ Deleted: Adelaide Metro Non-TOU (Green)
#   ✓ Deleted: Adelaide Metro TOU
#   ✓ Deleted: Adelaide Metro TOU (Green)
#   ✓ Deleted: Bunnings TOU
#   ✓ Deleted: Bunnings TOU (Green)
#   ✓ Deleted: CBUS TOU
#   ✓ Deleted: CBUS TOU (Green)
#   ✓ Deleted: Hentley Farm TOU
#   ✓ Deleted: Hentley Farm TOU (Green)
#   ✓ Deleted: KMART&TARGET TOU
#   ✓ Deleted: KMART&TARGET TOU (Green)
#   ✓ Deleted: SA Government Non-TOU
#   ✓ Deleted: SA Government Non-TOU (Green)
#   ✓ Deleted: SACOME TOU
#   ✓ Deleted: SACOME TOU (Green)
#   ✓ Deleted: Sarstedt TOU
#   ✓ Deleted: Sarstedt TOU (Green)
#   ✓ Deleted: Sekisui TOU
#   ✓ Deleted: Sekisui TOU (Green)
#   ✓ Deleted: St John Ambulance Non-TOU
#   ✓ Deleted: St John Ambulance Non-TOU (Green)
#   ✓ Deleted: Sundrop Farms TOU
#   ✓ Deleted: Sundrop Farms TOU (Green)
#   ✓ Deleted: Kings The Printer TOU
#   ✓ Deleted: SEEK TOU
#   ✓ Deleted: SEEK TOU (Green)
#   ✓ Deleted: Villa Maria TOU
#   ✓ Deleted: Villa Maria TOU (Green)
#   ✓ Deleted: Blue Grass Solar 202203
#   ✓ Deleted: Blue Grass Solar 202203 (Green)
#   ✓ Deleted: Cathedral Rocks Wind 202408
#   ✓ Deleted: Cathedral Rocks Wind 202408 (Green)
#   ✓ Deleted: Collector Wind 202403
#   ✓ Deleted: Collector Wind 202403 (Green)
#   ✓ Deleted: Diapur Wind 202212
#   ✓ Deleted: Diapur Wind 202212 (Green)
#   ✓ Deleted: Edenvale Solar 202411
#   ✓ Deleted: Ferguson Wind 202212
#   ✓ Deleted: Ferguson Wind 202212 (Green)
#   ✓ Deleted: Ginan Solar 202406
#   ✓ Deleted: Ginan Solar 202406 (Green)
#   ✓ Deleted: Gunnedah Solar 202407
#   ✓ Deleted: Hay Solar 202409
#   ✓ Deleted: Hillston 1 Solar 202409
#   ✓ Deleted: Hillston 2 Solar 202409
#   ✓ Deleted: Kerang Solar 202408
#   ✓ Deleted: Kerang Solar 202408 (Green)
#   ✓ Deleted: Kootingal Solar 202407
#   ✓ Deleted: Moree Solar 202202
#   ✓ Deleted: Moree Solar 202202 (Green)
#   ✓ Deleted: Mortons Lane Wind 202212
#   ✓ Deleted: Mortons Lane Wind 202212 (Green)
#   ✓ Deleted: Mulwala Solar 202209
#   ✓ Deleted: Mulwala Solar 202209 (Green)
#   ✓ Deleted: New England Solar 202412
#   ✓ Deleted: New England Solar 202412 (Green)
#   ✓ Deleted: Numurkah Solar 201810
#   ✓ Deleted: Numurkah Solar 201810 (Green)
#   ✓ Deleted: Numurkah Solar 202410
#   ✓ Deleted: Numurkah Solar 202410 (Green)
#   ✓ Deleted: Nyngan Solar 202212
#   ✓ Deleted: Nyngan Solar 202212 (Green)
#   ✓ Deleted: Quorn Solar 202406
#   ✓ Deleted: Quorn Solar 202406 (Green)
#   ✓ Deleted: Renmark Solar 202212
#   ✓ Deleted: Starfish Hill Wind 202403
#   ✓ Deleted: Starfish Hill Wind 202403 (Green)
#   ✓ Deleted: Tailem Bend 2 Solar 202203
#   ✓ Deleted: Tailem Bend 2 Solar 202203 (Green)
#   ✓ Deleted: Temora Solar 202407
#   ✓ Deleted: Wagga Wagga Solar 202303
#   ✓ Deleted: Wagga Wagga Solar 202303 (Green)
#   ✓ Deleted: Waubra Wind 202208
#   ✓ Deleted: Waubra Wind 202208 (Green)
#   ✓ Deleted: Waubra Wind 202401
#   ✓ Deleted: Waubra Wind 202401 (Green)
#   ✓ Deleted: Wemen Solar 201806
#   ✓ Deleted: Wemen Solar 201806 (Green)
#   ✓ Deleted: Woods Point Solar 202304
#   ✓ Deleted: CSIRO Non-TOU
#   ✓ Deleted: NSW Retail FY25 B
#   ✓ Deleted: NSW Retail FY25 Cap B
#   ✓ Deleted: NSW Retail FY25 Cap S
#   ✓ Deleted: NSW Retail FY25 S
#   ✓ Deleted: NSW Solar FY25 B
#   ✓ Deleted: NSW Solar FY25 Cap B
#   ✓ Deleted: NSW Solar FY25 Cap S
#   ✓ Deleted: NSW Solar FY25 Floor B
#   ✓ Deleted: NSW Solar FY25 Floor S
#   ✓ Deleted: NSW Solar FY25 S
#   ✓ Deleted: NSW Wind FY25 B
#   ✓ Deleted: NSW Wind FY25 Cap B
#   ✓ Deleted: NSW Wind FY25 Cap S
#   ✓ Deleted: NSW Wind FY25 Floor B
#   ✓ Deleted: NSW Wind FY25 Floor S
#   ✓ Deleted: NSW Wind FY25 S
#   ✓ Deleted: QLD Retail FY25 B
#   ✓ Deleted: QLD Retail FY25 S
#   ✓ Deleted: QLD Solar FY25 B
#   ✓ Deleted: QLD Solar FY25 Cap B
#   ✓ Deleted: QLD Solar FY25 Cap S
#   ✓ Deleted: QLD Solar FY25 Floor B
#   ✓ Deleted: QLD Solar FY25 Floor S
#   ✓ Deleted: QLD Solar FY25 S
#   ✓ Deleted: SA Retail FY25 B
#   ✓ Deleted: SA Retail FY25 Cap B
#   ✓ Deleted: SA Retail FY25 Cap S
#   ✓ Deleted: SA Retail FY25 S
#   ✓ Deleted: SA Solar FY25 B
#   ✓ Deleted: SA Solar FY25 Cap B
#   ✓ Deleted: SA Solar FY25 Cap S
#   ✓ Deleted: SA Solar FY25 Floor B
#   ✓ Deleted: SA Solar FY25 Floor S
#   ✓ Deleted: SA Solar FY25 S
#   ✓ Deleted: SA Wind FY25 B
#   ✓ Deleted: SA Wind FY25 Cap B
#   ✓ Deleted: SA Wind FY25 Cap S
#   ✓ Deleted: SA Wind FY25 Floor B
#   ✓ Deleted: SA Wind FY25 Floor S
#   ✓ Deleted: SA Wind FY25 S
#   ✓ Deleted: SE000350
#   ✓ Deleted: SE000352
#   ✓ Deleted: SE000354
#   ✓ Deleted: SE000780 (Green)
#   ✓ Deleted: SE000960 (Green)
#   ✓ Deleted: SE001052 (Green)
#   ✓ Deleted: SE001062
#   ✓ Deleted: SE001063
#   ✓ Deleted: SE001088
#   ✓ Deleted: SE001089
#   ✓ Deleted: SE001106 (Green)
#   ✓ Deleted: SE001139 (Green)
#   ✓ Deleted: SE001191 (Green)
#   ✓ Deleted: SE001194
#   ✓ Deleted: SE001272 (Green)
#   ✓ Deleted: SE001282 (Green)
#   ✓ Deleted: SE001317 (Green)
#   ✓ Deleted: SE001327
#   ✓ Deleted: SE001350 (Green)
#   ✓ Deleted: SE001368 (Green)
#   ✓ Deleted: SE001369
#   ✓ Deleted: SE001370
#   ✓ Deleted: SE001371
#   ✓ Deleted: SE001392 (Green)
#   ✓ Deleted: SE001399 (Green)
#   ✓ Deleted: SE001416 (Green)
#   ✓ Deleted: SE001447
#   ✓ Deleted: SE001449
#   ✓ Deleted: SE001452
#   ✓ Deleted: SE001453
#   ✓ Deleted: SE001455
#   ✓ Deleted: SE001458
#   ✓ Deleted: SE001459
#   ✓ Deleted: SE001470
#   ✓ Deleted: SE001479
#   ✓ Deleted: SE001480 (Green)
#   ✓ Deleted: SE001482 (Green)
#   ✓ Deleted: SE001490
#   ✓ Deleted: SE001491
#   ✓ Deleted: SE001494
#   ✓ Deleted: SE001498 (Green)
#   ✓ Deleted: SE001503
#   ✓ Deleted: SE001504
#   ✓ Deleted: SE001509
#   ✓ Deleted: SE001510
#   ✓ Deleted: SE001513
#   ✓ Deleted: SE001514
#   ✓ Deleted: SE001515 (Green)
#   ✓ Deleted: SE001516
#   ✓ Deleted: SE001517
#   ✓ Deleted: SE001523 (Green)
#   ✓ Deleted: SE001533
#   ✓ Deleted: SE001541 (Green)
#   ✓ Deleted: SE001547
#   ✓ Deleted: SE001550 (Green)
#   ✓ Deleted: SE001551 (Green)
#   ✓ Deleted: SE001572
#   ✓ Deleted: SE001573
#   ✓ Deleted: SE001574 (Green)
#   ✓ Deleted: SE001575 (Green)
#   ✓ Deleted: SE001578 (Green)
#   ✓ Deleted: SE001593 (Green)
#   ✓ Deleted: SE001600 (Green)
#   ✓ Deleted: SE001602
#   ✓ Deleted: SE001620
#   ✓ Deleted: SE001628 (Green)
#   ✓ Deleted: SE001629 (Green)
#   ✓ Deleted: SE001639 (Green)
#   ✓ Deleted: SE001641 (Green)
#   ✓ Deleted: SE001642
#   ✓ Deleted: SE001646
#   ✓ Deleted: SE001648
#   ✓ Deleted: SE001657
#   ✓ Deleted: SE001660 (Green)
#   ✓ Deleted: SE001662
#   ✓ Deleted: SE001668
#   ✓ Deleted: SE001669
#   ✓ Deleted: SE001670
#   ✓ Deleted: SE001671
#   ✓ Deleted: SE001675
#   ✓ Deleted: SE001676
#   ✓ Deleted: SE001677
#   ✓ Deleted: SE001678
#   ✓ Deleted: SE001679
#   ✓ Deleted: SE001685
#   ✓ Deleted: SE001690
#   ✓ Deleted: SE001691
#   ✓ Deleted: SE001709
#   ✓ Deleted: SE001712
#   ✓ Deleted: SE001718
#   ✓ Deleted: SE001720
#   ✓ Deleted: SE001721
#   ✓ Deleted: SE001736
#   ✓ Deleted: SE001738
#   ✓ Deleted: SE001739
#   ✓ Deleted: SE001760
#   ✓ Deleted: SE001761
#   ✓ Deleted: SE001762
#   ✓ Deleted: SE001763
#   ✓ Deleted: SE001765
#   ✓ Deleted: SE001767
#   ✓ Deleted: SE001768
#   ✓ Deleted: SE001769
#   ✓ Deleted: SE001770
#   ✓ Deleted: SE001772
#   ✓ Deleted: SE001782
#   ✓ Deleted: SE001783
#   ✓ Deleted: SE001837
#   ✓ Deleted: SE001840
#   ✓ Deleted: SE001841
#   ✓ Deleted: SE001845
#   ✓ Deleted: SE001846
#   ✓ Deleted: SE001847
#   ✓ Deleted: SE001848
#   ✓ Deleted: SE001874
#   ✓ Deleted: SE001876
#   ✓ Deleted: SE001888
#   ✓ Deleted: SE001889
#   ✓ Deleted: SE001890
#   ✓ Deleted: SE001891
#   ✓ Deleted: SE001896
#   ✓ Deleted: SE001897
#   ✓ Deleted: SE001902
#   ✓ Deleted: SE001903
#   ✓ Deleted: SE001904
#   ✓ Deleted: SE001905
#   ✓ Deleted: SE001906
#   ✓ Deleted: SE001907
#   ✓ Deleted: SE001908
#   ✓ Deleted: SE001912
#   ✓ Deleted: SE001913
#   ✓ Deleted: SE001914
#   ✓ Deleted: SE001916
#   ✓ Deleted: SE001917
#   ✓ Deleted: SE001920
#   ✓ Deleted: SE001921
#   ✓ Deleted: SE001933
#   ✓ Deleted: SE001945
#   ✓ Deleted: SE001947
#   ✓ Deleted: SE001952
#   ✓ Deleted: SE001959
#   ✓ Deleted: SE001960
#   ✓ Deleted: SE001979
#   ✓ Deleted: SE001981
#   ✓ Deleted: SE001982
#   ✓ Deleted: SE001986
#   ✓ Deleted: SE001989
#   ✓ Deleted: SE002021
#   ✓ Deleted: SE002049
#   ✓ Deleted: SE002050 (Green)
#   ✓ Deleted: SE002051 (Green)
#   ✓ Deleted: SE002052 (Green)
#   ✓ Deleted: SE002053 (Green)
#   ✓ Deleted: SE002054 (Green)
#   ✓ Deleted: SE002055 (Green)
#   ✓ Deleted: SE002056 (Green)
#   ✓ Deleted: SE002057 (Green)
#   ✓ Deleted: SE002058 (Green)
#   ✓ Deleted: SE002059 (Green)
#   ✓ Deleted: SE002060 (Green)
#   ✓ Deleted: SE002061 (Green)
#   ✓ Deleted: SE002062
#   ✓ Deleted: SE002063
#   ✓ Deleted: SE002077
#   ✓ Deleted: SE002078
#   ✓ Deleted: SE002091
#   ✓ Deleted: SE002097 (Green)
#   ✓ Deleted: SE002103
#   ✓ Deleted: SE002105 (Green)
#   ✓ Deleted: SE002141
#   ✓ Deleted: SE002153
#   ✓ Deleted: SE002154
#   ✓ Deleted: SE002155
#   ✓ Deleted: SE002157
#   ✓ Deleted: SE002159 (Green)
#   ✓ Deleted: SE002161
#   ✓ Deleted: SE002163
#   ✓ Deleted: SE002164
#   ✓ Deleted: SE002165
#   ✓ Deleted: SE002166
#   ✓ Deleted: SE002169
#   ✓ Deleted: SE002171
#   ✓ Deleted: SE002172
#   ✓ Deleted: SE002173
#   ✓ Deleted: SE002174
#   ✓ Deleted: SE002175
#   ✓ Deleted: SE002176
#   ✓ Deleted: SE002178
#   ✓ Deleted: SE002179
#   ✓ Deleted: SE002180
#   ✓ Deleted: SE002182
#   ✓ Deleted: SE002183
#   ✓ Deleted: SE002184
#   ✓ Deleted: SE002185
#   ✓ Deleted: SE002186
#   ✓ Deleted: SE002191
#   ✓ Deleted: SE002193
#   ✓ Deleted: SE002194
#   ✓ Deleted: SE002195
#   ✓ Deleted: SE002196
#   ✓ Deleted: SE002197
#   ✓ Deleted: SE002198
#   ✓ Deleted: SE002199
#   ✓ Deleted: SE002200
#   ✓ Deleted: SE002201
#   ✓ Deleted: SE002202
#   ✓ Deleted: SE002203
#   ✓ Deleted: SE002211
#   ✓ Deleted: SE002212
#   ✓ Deleted: SE002213 (Green)
#   ✓ Deleted: SE002214 (Green)
#   ✓ Deleted: SE002215 (Green)
#   ✓ Deleted: SE002216 (Green)
#   ✓ Deleted: SE002217 (Green)
#   ✓ Deleted: SE002218 (Green)
#   ✓ Deleted: SE002219 (Green)
#   ✓ Deleted: SE002220 (Green)
#   ✓ Deleted: SE002221 (Green)
#   ✓ Deleted: SE002222 (Green)
#   ✓ Deleted: SE002223 (Green)
#   ✓ Deleted: SE002224 (Green)
#   ✓ Deleted: SE002225 (Green)
#   ✓ Deleted: SE002226 (Green)
#   ✓ Deleted: SE002227 (Green)
#   ✓ Deleted: SE002228 (Green)
#   ✓ Deleted: SE002229 (Green)
#   ✓ Deleted: SE002232
#   ✓ Deleted: SE002233
#   ✓ Deleted: SE002234
#   ✓ Deleted: SE002235
#   ✓ Deleted: SE002236
#   ✓ Deleted: SE002252 (Green)
#   ✓ Deleted: SE002253 (Green)
#   ✓ Deleted: SE002254 (Green)
#   ✓ Deleted: SE002255
#   ✓ Deleted: SE002256
#   ✓ Deleted: SE002257
#   ✓ Deleted: SE002258
#   ✓ Deleted: SE002259
#   ✓ Deleted: SE002260
#   ✓ Deleted: SE002262 (Green)
#   ✓ Deleted: SE002263
#   ✓ Deleted: SE002266 (Green)
#   ✓ Deleted: SE002267 (Green)
#   ✓ Deleted: SE002268
#   ✓ Deleted: SE002269
#   ✓ Deleted: SE002270 (Green)
#   ✓ Deleted: SE002271 (Green)
#   ✓ Deleted: SE002272 (Green)
#   ✓ Deleted: SE002273 (Green)
#   ✓ Deleted: SE002274 (Green)
#   ✓ Deleted: SE002275 (Green)
#   ✓ Deleted: SE002276 (Green)
#   ✓ Deleted: SE002277 (Green)
#   ✓ Deleted: SE002278 (Green)
#   ✓ Deleted: Templers
#   ✓ Deleted: VIC Retail FY25 B
#   ✓ Deleted: VIC Retail FY25 Cap B
#   ✓ Deleted: VIC Retail FY25 Cap S
#   ✓ Deleted: VIC Retail FY25 S
#   ✓ Deleted: VIC Solar FY25 B
#   ✓ Deleted: VIC Solar FY25 Cap B
#   ✓ Deleted: VIC Solar FY25 Cap S
#   ✓ Deleted: VIC Solar FY25 Floor B
#   ✓ Deleted: VIC Solar FY25 Floor S
#   ✓ Deleted: VIC Solar FY25 S
#   ✓ Deleted: VIC Wind FY25 B
#   ✓ Deleted: VIC Wind FY25 Cap B
#   ✓ Deleted: VIC Wind FY25 Cap S
#   ✓ Deleted: VIC Wind FY25 Floor B
#   ✓ Deleted: VIC Wind FY25 Floor S
#   ✓ Deleted: VIC Wind FY25 S
#
# Database clearing summary:
#   Deleted: 412
#   Errors: 0
#   Total processed: 412
# Database cleared successfully!
#
# Loaded CSV with 9230 rows and columns: ['Trade', 'Deal_name', 'New_deal_name', 'State', 'type', 'MonthStart', 'MonthEnd', 'StartDate', 'EndDate', 'Month', 'Year', 'annualVolume', 'AvestrikePrice', 'unit', 'ContractType', 'Sub_Type', 'Strike_Price_Timeseries', 'Unnamed: 17', 'Cap_Floor_Strike_price', ' Volume ', 'LWP_DWP_%', 'MtM']
# Actual CSV columns (after cleaning): ['Trade', 'Deal_name', 'New_deal_name', 'State', 'type', 'MonthStart', 'MonthEnd', 'StartDate', 'EndDate', 'Month', 'Year', 'annualVolume', 'AvestrikePrice', 'unit', 'ContractType', 'Sub_Type', 'Strike_Price_Timeseries', 'Unnamed: 17', 'Cap_Floor_Strike_price', 'Volume', 'LWP_DWP_%', 'MtM']
# Processing Volume column...
# Sample Volume data: [41, 12, 33, 25, 41]
# Cleaned data: 9230 rows remaining
# Contract: BVC TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: BVC TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: CSIRO TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: CSIRO TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Fairfield Non-TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026]
# Contract: Fairfield Non-TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026]
# Contract: Fairfield TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026]
# Contract: Fairfield TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026]
# Contract: Occupier Non-TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041]
# Contract: SBS TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: SBS TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: SSROC Non-TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026]
# Contract: SSROC Non-TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026]
# Contract: SSROC TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026]
# Contract: SSROC TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026]
# Contract: ISPT Non-TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031]
# Contract: ISPT Non-TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: ISPT TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: ISPT TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Adelaide Metro Non-TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Adelaide Metro Non-TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Adelaide Metro TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Adelaide Metro TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Bunnings TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027]
# Contract: Bunnings TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027]
# Contract: CBUS TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: CBUS TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Hentley Farm TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Hentley Farm TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: KMART&TARGET TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: KMART&TARGET TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: SA Government Non-TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031]
# Contract: SA Government Non-TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: SACOME TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027]
# Contract: SACOME TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027]
# Contract: Sarstedt TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Sarstedt TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Sekisui TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027]
# Contract: Sekisui TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027]
# Contract: St John Ambulance Non-TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: St John Ambulance Non-TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Sundrop Farms TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Sundrop Farms TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025]
# Contract: Kings The Printer TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028]
# Contract: SEEK TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: SEEK TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Villa Maria TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027]
# Contract: Villa Maria TOU (Green) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027]
# Contract: Blue Grass Solar 202203 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Blue Grass Solar 202203 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Cathedral Rocks Wind 202408 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: Cathedral Rocks Wind 202408 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: Collector Wind 202403 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: Collector Wind 202403 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: Diapur Wind 202212 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Diapur Wind 202212 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Edenvale Solar 202411 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025]
# Contract: Ferguson Wind 202212 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Ferguson Wind 202212 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Ginan Solar 202406 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028]
# Contract: Ginan Solar 202406 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028]
# Contract: Gunnedah Solar 202407 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Hay Solar 202409 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Hillston 1 Solar 202409 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Hillston 2 Solar 202409 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Kerang Solar 202408 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035]
# Contract: Kerang Solar 202408 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035]
# Contract: Kootingal Solar 202407 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Moree Solar 202202 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026]
# Contract: Moree Solar 202202 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026]
# Contract: Mortons Lane Wind 202212 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Mortons Lane Wind 202212 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Mulwala Solar 202209 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033]
# Contract: Mulwala Solar 202209 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033]
# Contract: New England Solar 202412 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035]
# Contract: New England Solar 202412 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035]
# Contract: Numurkah Solar 201810 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: Numurkah Solar 201810 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: Numurkah Solar 202410 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: Numurkah Solar 202410 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: Nyngan Solar 202212 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033]
# Contract: Nyngan Solar 202212 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033]
# Contract: Quorn Solar 202406 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036]
# Contract: Quorn Solar 202406 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036]
# Contract: Renmark Solar 202212 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025]
# Contract: Starfish Hill Wind 202403 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: Starfish Hill Wind 202403 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034]
# Contract: Tailem Bend 2 Solar 202203 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038]
# Contract: Tailem Bend 2 Solar 202203 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038]
# Contract: Temora Solar 202407 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: Wagga Wagga Solar 202303 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033]
# Contract: Wagga Wagga Solar 202303 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033]
# Contract: Waubra Wind 202208 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Waubra Wind 202208 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Waubra Wind 202401 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Waubra Wind 202401 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2026, 2027, 2028, 2029, 2030, 2031, 2032]
# Contract: Wemen Solar 201806 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026]
# Contract: Wemen Solar 201806 (Green) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026]
# Contract: Woods Point Solar 202304 (Energy) - Type: offtake - Unit: MWh - Trade: buy - Years: [2025, 2026]
# Contract: CSIRO Non-TOU (Energy) - Type: retail - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030]
# Contract: Hillston (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031]
# Contract: Merredin (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2028, 2029, 2030]
# Contract: Molong (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031]
# Contract: Nevertire (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2029, 2030]
# Contract: NSW Retail FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: NSW Retail FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: NSW Retail FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: NSW Retail FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: NSW Solar FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: NSW Solar FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: NSW Solar FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: NSW Solar FY25 Floor B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: NSW Solar FY25 Floor S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: NSW Solar FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: NSW Wind FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: NSW Wind FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: NSW Wind FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: NSW Wind FY25 Floor B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: NSW Wind FY25 Floor S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: NSW Wind FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: QLD Retail FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: QLD Retail FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: QLD Solar FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: QLD Solar FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: QLD Solar FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: QLD Solar FY25 Floor B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: QLD Solar FY25 Floor S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: QLD Solar FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SA Retail FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SA Retail FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SA Retail FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SA Retail FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SA Solar FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SA Solar FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SA Solar FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SA Solar FY25 Floor B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SA Solar FY25 Floor S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SA Solar FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SA Wind FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SA Wind FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SA Wind FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SA Wind FY25 Floor B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SA Wind FY25 Floor S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SA Wind FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE000350 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025, 2026, 2027]
# Contract: SE000352 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025, 2026, 2027]
# Contract: SE000354 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: SE000780 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE000960 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001052 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001062 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: SE001063 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029]
# Contract: SE001088 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038]
# Contract: SE001089 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038]
# Contract: SE001106 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001139 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001191 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001194 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001272 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE001282 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE001317 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001327 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001350 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001368 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001369 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001370 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001371 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001392 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001399 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001416 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE001447 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001449 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001452 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001453 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001455 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001458 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001459 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001470 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001479 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001480 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001482 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001490 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001491 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001494 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001498 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001503 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001504 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001509 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001510 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001513 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001514 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001515 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2027]
# Contract: SE001516 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001517 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001523 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001533 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001541 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001547 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025, 2026]
# Contract: SE001550 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001551 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001572 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001573 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001574 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001575 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001578 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001593 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001600 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE001602 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001620 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001628 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001629 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE001639 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001641 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001642 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025, 2026]
# Contract: SE001646 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001648 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001657 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001660 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001662 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001668 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001669 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001670 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001671 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001675 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001676 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001677 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001678 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001679 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001685 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001690 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001691 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001709 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE001712 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001718 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001720 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001721 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001736 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001738 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001739 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001760 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001761 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001762 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001763 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001765 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001767 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001768 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001769 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001770 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001772 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001782 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001783 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001837 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001840 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001841 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001845 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001846 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001847 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001848 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001874 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001876 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001888 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001889 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001890 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001891 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001896 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001897 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001902 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001903 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001904 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001905 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001906 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001907 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001908 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001912 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001913 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001914 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001916 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001917 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001920 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001921 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE001933 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001945 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001947 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE001952 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001959 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001960 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001979 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001981 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001982 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001986 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE001989 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002021 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002049 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002050 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002051 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002052 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002053 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002054 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002055 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002056 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002057 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE002058 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE002059 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE002060 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE002061 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2028]
# Contract: SE002062 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002063 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002077 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002078 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002091 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002097 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE002103 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002105 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002141 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002153 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002154 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002155 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002157 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002159 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2027]
# Contract: SE002161 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002163 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002164 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002165 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002166 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002169 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002171 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002172 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002173 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002174 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE002175 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE002176 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002178 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002179 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002180 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002182 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002183 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002184 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002185 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002186 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002191 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002193 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002194 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002195 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002196 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002197 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002198 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002199 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE002200 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE002201 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025]
# Contract: SE002202 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002203 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025]
# Contract: SE002211 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026]
# Contract: SE002212 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002213 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002214 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002215 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026]
# Contract: SE002216 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE002217 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# Contract: SE002218 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027]
# ...
#
# Processing: SE002203 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002203 (ID: 6847934fa9ed324d11af4b06)
#
# Processing: SE002211 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026] - 12 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002211 (ID: 6847934fa9ed324d11af4b07)
#
# Processing: SE002212 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026] - 12 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002212 (ID: 6847934fa9ed324d11af4b08)
#
# Processing: SE002213 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002213 (Green) (ID: 6847934fa9ed324d11af4b09)
#
# Processing: SE002214 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002214 (Green) (ID: 6847934fa9ed324d11af4b0a)
#
# Processing: SE002215 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002215 (Green) (ID: 6847934fa9ed324d11af4b0b)
#
# Processing: SE002216 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002216 (Green) (ID: 6847934fa9ed324d11af4b0c)
#
# Processing: SE002217 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002217 (Green) (ID: 6847934fa9ed324d11af4b0d)
#
# Processing: SE002218 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002218 (Green) (ID: 6847934fa9ed324d11af4b0e)
#
# Processing: SE002219 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2027] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002219 (Green) (ID: 68479350a9ed324d11af4b0f)
#
# Processing: SE002220 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2028] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002220 (Green) (ID: 68479350a9ed324d11af4b10)
#
# Processing: SE002221 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2028] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002221 (Green) (ID: 68479350a9ed324d11af4b11)
#
# Processing: SE002222 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2028] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002222 (Green) (ID: 68479350a9ed324d11af4b12)
#
# Processing: SE002223 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2028] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002223 (Green) (ID: 68479350a9ed324d11af4b13)
#
# Processing: SE002224 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2029] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002224 (Green) (ID: 68479350a9ed324d11af4b14)
#
# Processing: SE002225 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2029] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002225 (Green) (ID: 68479350a9ed324d11af4b15)
#
# Processing: SE002226 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2029] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002226 (Green) (ID: 68479350a9ed324d11af4b16)
#
# Processing: SE002227 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2029] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002227 (Green) (ID: 68479350a9ed324d11af4b17)
#
# Processing: SE002228 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2030] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002228 (Green) (ID: 68479350a9ed324d11af4b18)
#
# Processing: SE002229 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2030] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002229 (Green) (ID: 68479351a9ed324d11af4b19)
#
# Processing: SE002232 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002232 (ID: 68479351a9ed324d11af4b1a)
#
# Processing: SE002233 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002233 (ID: 68479351a9ed324d11af4b1b)
#
# Processing: SE002234 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002234 (ID: 68479351a9ed324d11af4b1c)
#
# Processing: SE002235 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002235 (ID: 68479351a9ed324d11af4b1d)
#
# Processing: SE002236 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002236 (ID: 68479351a9ed324d11af4b1e)
#
# Processing: SE002252 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2030] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002252 (Green) (ID: 68479351a9ed324d11af4b1f)
#
# Processing: SE002253 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2030] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002253 (Green) (ID: 68479351a9ed324d11af4b20)
#
# Processing: SE002254 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2031] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002254 (Green) (ID: 68479351a9ed324d11af4b21)
#
# Processing: SE002255 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002255 (ID: 68479351a9ed324d11af4b22)
#
# Processing: SE002256 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002256 (ID: 68479352a9ed324d11af4b23)
#
# Processing: SE002257 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002257 (ID: 68479352a9ed324d11af4b24)
#
# Processing: SE002258 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002258 (ID: 68479352a9ed324d11af4b25)
#
# Processing: SE002259 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002259 (ID: 68479352a9ed324d11af4b26)
#
# Processing: SE002260 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002260 (ID: 68479352a9ed324d11af4b27)
#
# Processing: SE002262 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2026] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002262 (Green) (ID: 68479352a9ed324d11af4b28)
#
# Processing: SE002263 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 3 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002263 (ID: 68479352a9ed324d11af4b29)
#
# Processing: SE002266 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002266 (Green) (ID: 68479352a9ed324d11af4b2a)
#
# Processing: SE002267 (Green) - Type: wholesale - Unit: MW - Trade: buy - Years: [2026] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002267 (Green) (ID: 68479352a9ed324d11af4b2b)
#
# Processing: SE002268 (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002268 (ID: 68479352a9ed324d11af4b2c)
#
# Processing: SE002269 (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002269 (ID: 68479353a9ed324d11af4b2d)
#
# Processing: SE002270 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002270 (Green) (ID: 68479353a9ed324d11af4b2e)
#
# Processing: SE002271 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002271 (Green) (ID: 68479353a9ed324d11af4b2f)
#
# Processing: SE002272 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002272 (Green) (ID: 68479353a9ed324d11af4b30)
#
# Processing: SE002273 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002273 (Green) (ID: 68479353a9ed324d11af4b31)
#
# Processing: SE002274 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002274 (Green) (ID: 68479353a9ed324d11af4b32)
#
# Processing: SE002275 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002275 (Green) (ID: 68479353a9ed324d11af4b33)
#
# Processing: SE002276 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002276 (Green) (ID: 68479353a9ed324d11af4b34)
#
# Processing: SE002277 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002277 (Green) (ID: 68479353a9ed324d11af4b35)
#
# Processing: SE002278 (Green) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 1 data points
#   → No existing contract found, will create new one
# Successfully created contract: SE002278 (Green) (ID: 68479353a9ed324d11af4b36)
#
# Processing: Templers (Energy) - Type: offtake - Unit: MWh - Trade: sell - Years: [2025, 2026, 2027, 2028, 2029, 2030, 2031, 2032, 2033, 2034, 2035, 2036, 2037, 2038, 2039, 2040, 2041, 2042, 2043, 2044, 2045] - 242 data points
#   → No existing contract found, will create new one
# Successfully created contract: Templers (ID: 68479353a9ed324d11af4b37)
#
# Processing: VIC Retail FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Retail FY25 B (ID: 68479354a9ed324d11af4b38)
#
# Processing: VIC Retail FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Retail FY25 Cap B (ID: 68479354a9ed324d11af4b39)
#
# Processing: VIC Retail FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Retail FY25 Cap S (ID: 68479354a9ed324d11af4b3a)
#
# Processing: VIC Retail FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Retail FY25 S (ID: 68479354a9ed324d11af4b3b)
#
# Processing: VIC Solar FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 B (ID: 68479354a9ed324d11af4b3c)
#
# Processing: VIC Solar FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 Cap B (ID: 68479354a9ed324d11af4b3d)
#
# Processing: VIC Solar FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 Cap S (ID: 68479354a9ed324d11af4b3e)
#
# Processing: VIC Solar FY25 Floor B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 Floor B (ID: 68479354a9ed324d11af4b3f)
#
# Processing: VIC Solar FY25 Floor S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 Floor S (ID: 68479354a9ed324d11af4b40)
#
# Processing: VIC Solar FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Solar FY25 S (ID: 68479355a9ed324d11af4b41)
#
# Processing: VIC Wind FY25 B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 B (ID: 68479355a9ed324d11af4b42)
#
# Processing: VIC Wind FY25 Cap B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 Cap B (ID: 68479355a9ed324d11af4b43)
#
# Processing: VIC Wind FY25 Cap S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 Cap S (ID: 68479355a9ed324d11af4b44)
#
# Processing: VIC Wind FY25 Floor B (Energy) - Type: wholesale - Unit: MW - Trade: buy - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 Floor B (ID: 68479355a9ed324d11af4b45)
#
# Processing: VIC Wind FY25 Floor S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 Floor S (ID: 68479355a9ed324d11af4b46)
#
# Processing: VIC Wind FY25 S (Energy) - Type: wholesale - Unit: MW - Trade: sell - Years: [2025] - 4 data points
#   → No existing contract found, will create new one
# Successfully created contract: VIC Wind FY25 S (ID: 68479355a9ed324d11af4b47)
#
# ==================================================
# IMPORT SUMMARY (LIVE RUN)
# ==================================================
# Contracts created: 412
# Contracts updated: 0
# Errors: 4
# Total processed: 416
